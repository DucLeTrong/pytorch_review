# %% [markdown]
# <a href="https://colab.research.google.com/github/DucLeTrong/pytorch_review/blob/master/2_pytorch_tensor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
dtype = torch.float
device = torch.device("cpu")

# %%
N, D_in, H, D_out = 64, 1000, 100, 10

# %%
x = torch.randn(N,D_in, device=device, dtype=dtype)
y = torch.randn(N,D_out, device=device, dtype=dtype)

# %%
w1 = torch.randn(D_in, H, device=device, dtype=dtype)
w2 = torch.randn(H, D_out, device=device, dtype=dtype)

# %%
# w1
# a = torch.tensor([[1,2,3]],device=device, dtype=dtype)
# b = torch.tensor([[2,3,4]],device=device, dtype=dtype)

# %%
# a = a if a >2 else 0 
# a

# %%
# a.clamp(max=2)

# %%
# w2

# %%
learning_rate = 1e-6

# %%
# w1

# %%
# w2

# %%
# y

# %%
for t in range(500):
    h = x.mm(w1)
    # print(h)
    h_relu = h.clamp(min=0)
    # print(h_relu)
    y_pred = h_relu.mm(w2)
    # print(y_pred)

    loss = (y_pred - y).pow(2).sum()
    print(t, loss.item())

    #backwark
    grad_y_pred = 2.0 * (y_pred -y)
    grad_w2 = h_relu.t().mm(grad_y_pred)
    grad_h_relu = grad_y_pred.mm(w2.t())
    # grad_h = grad_h_relu.clamp(min=0)
    grad_h = grad_h_relu.clone()
    grad_h[h < 0] = 0
    grad_w1 = x.t().mm(grad_h)

    # Update weight
    w1 -= learning_rate * grad_w1
    w2 -= learning_rate * grad_w2
# Out:
# 0 28736954.0
# 1 24595144.0
# 2 25484704.0
# 3 27618282.0
# 4 27659408.0
# 5 23805638.0
# 6 16951008.0
# 7 10290074.0
# 8 5678221.0
# 9 3130046.5
# 10 1851068.25
# 11 1218520.5
# 12 887718.25
# 13 697351.25
# 14 574125.75
# 15 485812.96875
# 16 417709.0
# 17 362761.53125
# 18 317148.78125
# 19 278691.25
# 20 245880.6875
# 21 217703.03125
# 22 193354.40625
# 23 172227.21875
# 24 153799.9375
# 25 137668.875
# 26 123493.8125
# 27 111013.6953125
# 28 100001.671875
# 29 90253.2265625
# 30 81596.0078125
# 31 73886.8671875
# 32 67014.3046875
# 33 60875.9375
# 34 55381.35546875
# 35 50455.8828125
# 36 46030.6875
# 37 42041.69921875
# 38 38441.921875
# 39 35190.48046875
# 40 32247.84765625
# 41 29581.6953125
# 42 27163.125
# 43 24965.64453125
# 44 22967.6796875
# 45 21147.015625
# 46 19487.037109375
# 47 17971.255859375
# 48 16585.83203125
# 49 15318.244140625
# 50 14158.048828125
# 51 13094.90234375
# 52 12119.337890625
# 53 11223.408203125
# 54 10399.951171875
# 55 9642.748046875
# ...
