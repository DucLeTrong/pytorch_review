# %% [markdown]
# <a href="https://colab.research.google.com/github/DucLeTrong/pytorch_review/blob/master/3_tensor_and_autograd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
dtype = torch.float
device = torch.device('cpu')

# %%
N, D_in, H, D_out = 64, 1000, 100 ,10

x = torch.randn(N, D_in, device=device, dtype=dtype)
y = torch.randn(N, D_out, device=device, dtype=dtype)

# %%
#Randomly initalize weight
w1 = torch.randn(D_in, H, device=device, dtype=dtype, requires_grad=True)
w2 = torch.randn(H, D_out, device=device, dtype=dtype, requires_grad=True)

learning_rate = 1e-6

# %%
for t in range(500):
    h = x.mm(w1)
    h_relu = h.clamp(min=0)
    y_pred = h_relu.mm(w2)

    #Compute and print loss
    loss = (y_pred -y).pow(2).sum()
    print(t, loss.item())

    # Backprop 
    loss.backward()

    with torch.no_grad():
        w1 -= learning_rate * w1.grad
        w2 -= learning_rate * w2.grad

        w1.grad.zero_()
        w2.grad.zero_()
# Out:
# 0 31210822.0
# 1 24787388.0
# 2 21334304.0
# 3 18066992.0
# 4 14273437.0
# 5 10382252.0
# 6 7087442.0
# 7 4671669.0
# 8 3080845.75
# 9 2084844.0
# 10 1470778.5
# 11 1086254.125
# 12 837266.25
# 13 668513.3125
# 14 548289.5625
# 15 458625.375
# 16 389118.125
# 17 333643.03125
# 18 288438.90625
# 19 250960.3125
# 20 219475.890625
# 21 192761.328125
# 22 169926.484375
# 23 150295.5
# 24 133337.75
# 25 118604.4375
# 26 105762.1875
# 27 94519.484375
# 28 84650.8515625
# 29 75976.9140625
# 30 68334.75
# 31 61567.9765625
# 32 55567.04296875
# 33 50231.9921875
# 34 45471.5859375
# 35 41216.9765625
# 36 37408.32421875
# 37 33991.53515625
# 38 30924.630859375
# 39 28165.94921875
# 40 25681.3515625
# 41 23437.79296875
# 42 21409.69921875
# 43 19575.09765625
# 44 17914.6484375
# 45 16409.12109375
# 46 15040.3720703125
# 47 13795.6474609375
# 48 12663.609375
# 49 11632.90625
# 50 10692.91796875
# 51 9836.6845703125
# 52 9054.828125
# 53 8339.6689453125
# 54 7685.3349609375
# 55 7086.89111328125
# ...
