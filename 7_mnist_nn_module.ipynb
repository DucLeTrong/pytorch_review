# %% [markdown]
# <a href="https://colab.research.google.com/github/DucLeTrong/pytorch_review/blob/master/7_mnist_nn_module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pathlib import Path
import requests

DATA_PATH = Path("data")
PATH = DATA_PATH / "mnist"

PATH.mkdir(parents=True, exist_ok=True)

URL = "http://deeplearning.net/data/mnist/"
FILENAME = "mnist.pkl.gz"

if not (PATH / FILENAME).exists():
        content = requests.get(URL + FILENAME).content
        (PATH / FILENAME).open("wb").write(content)

# %%
import pickle
import gzip

with gzip.open((PATH / FILENAME).as_posix(), "rb") as f:
        ((x_train, y_train), (x_valid, y_valid), _) = pickle.load(f, encoding="latin-1")

# %%
from matplotlib import pyplot
import numpy as np

pyplot.imshow(x_train[0].reshape((28, 28)), cmap="gray")
print(x_train.shape)
# Out:
# (50000, 784)

# %%
import torch

x_train, y_train, x_valid, y_valid = map(
    torch.tensor, (x_train, y_train, x_valid, y_valid)
)
n, c = x_train.shape

# %%
import math 
class MyModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.weights = torch.nn.Parameter(torch.randn(784,10) /math.sqrt(784))
        self.bias = torch.nn.Parameter(torch.zeros(10))
    def forward(self, xb):
        return log_softmax(xb @ self.weights + self.bias)

# %%
model = MyModel()

# %%
def log_softmax(x):
    return x - x.exp().sum(-1).log().unsqueeze(-1)

# %%
def nll(input, target):
    # print(input[range(target.shape[0])])
    return -input[range(target.shape[0]), target].mean()

loss_func = nll

# %%
def accuracy(out, yb):
    preds = torch.argmax(out, dim=1)
    return (preds == yb).float().mean()

# %%
from IPython.core.debugger import set_trace
bs = 64
lr = 0.5  # learning rate
epochs = 2  # how many epochs to train for

n, c = x_train.shape

# %%
def fit():
    for epoch in range(epochs):
        for i in range((n-1)//bs + 1):
            start_i = i*bs
            end_i = start_i + bs
            xb = x_train[start_i:end_i]
            yb = y_train[start_i:end_i]
            pred = model(xb)

            loss = loss_func(pred,yb)
            print(i, loss)
            loss.backward()
            with torch.no_grad():
                for parameter in model.parameters():
                    parameter -= parameter.grad * lr
                model.zero_grad()

# %%
fit()
# Out:
# 0 tensor(2.3906, grad_fn=<NegBackward>)
# 1 tensor(1.8071, grad_fn=<NegBackward>)
# 2 tensor(1.8196, grad_fn=<NegBackward>)
# 3 tensor(1.5746, grad_fn=<NegBackward>)
# 4 tensor(1.2875, grad_fn=<NegBackward>)
# 5 tensor(0.9809, grad_fn=<NegBackward>)
# 6 tensor(0.9135, grad_fn=<NegBackward>)
# 7 tensor(1.0545, grad_fn=<NegBackward>)
# 8 tensor(0.9469, grad_fn=<NegBackward>)
# 9 tensor(1.1363, grad_fn=<NegBackward>)
# 10 tensor(0.9430, grad_fn=<NegBackward>)
# 11 tensor(0.9830, grad_fn=<NegBackward>)
# 12 tensor(0.8125, grad_fn=<NegBackward>)
# 13 tensor(0.9414, grad_fn=<NegBackward>)
# 14 tensor(1.0678, grad_fn=<NegBackward>)
# 15 tensor(0.7524, grad_fn=<NegBackward>)
# 16 tensor(0.9703, grad_fn=<NegBackward>)
# 17 tensor(0.9397, grad_fn=<NegBackward>)
# 18 tensor(0.5276, grad_fn=<NegBackward>)
# 19 tensor(0.6482, grad_fn=<NegBackward>)
# 20 tensor(0.6716, grad_fn=<NegBackward>)
# 21 tensor(1.0270, grad_fn=<NegBackward>)
# 22 tensor(1.0788, grad_fn=<NegBackward>)
# 23 tensor(0.9034, grad_fn=<NegBackward>)
# 24 tensor(0.5058, grad_fn=<NegBackward>)
# 25 tensor(0.5364, grad_fn=<NegBackward>)
# 26 tensor(0.4192, grad_fn=<NegBackward>)
# 27 tensor(0.5312, grad_fn=<NegBackward>)
# 28 tensor(0.5912, grad_fn=<NegBackward>)
# 29 tensor(0.4857, grad_fn=<NegBackward>)
# 30 tensor(0.4691, grad_fn=<NegBackward>)
# 31 tensor(0.5247, grad_fn=<NegBackward>)
# 32 tensor(0.4628, grad_fn=<NegBackward>)
# 33 tensor(0.3352, grad_fn=<NegBackward>)
# 34 tensor(0.4981, grad_fn=<NegBackward>)
# 35 tensor(0.4498, grad_fn=<NegBackward>)
# 36 tensor(0.4010, grad_fn=<NegBackward>)
# 37 tensor(0.6046, grad_fn=<NegBackward>)
# 38 tensor(0.4526, grad_fn=<NegBackward>)
# 39 tensor(0.3452, grad_fn=<NegBackward>)
# 40 tensor(0.4238, grad_fn=<NegBackward>)
# 41 tensor(0.6027, grad_fn=<NegBackward>)
# 42 tensor(0.6026, grad_fn=<NegBackward>)
# 43 tensor(0.5027, grad_fn=<NegBackward>)
# 44 tensor(0.3442, grad_fn=<NegBackward>)
# 45 tensor(0.4826, grad_fn=<NegBackward>)
# 46 tensor(0.4096, grad_fn=<NegBackward>)
# 47 tensor(0.6314, grad_fn=<NegBackward>)
# 48 tensor(0.4123, grad_fn=<NegBackward>)
# 49 tensor(0.3473, grad_fn=<NegBackward>)
# 50 tensor(0.4150, grad_fn=<NegBackward>)
# 51 tensor(0.4651, grad_fn=<NegBackward>)
# 52 tensor(0.4152, grad_fn=<NegBackward>)
# 53 tensor(0.4558, grad_fn=<NegBackward>)
# 54 tensor(0.4226, grad_fn=<NegBackward>)
# 55 tensor(0.5222, grad_fn=<NegBackward>)
# 56 tensor(0.2891, grad_fn=<NegBackward>)
# 57 tensor(0.5169, grad_fn=<NegBackward>)
# 58 tensor(0.5488, grad_fn=<NegBackward>)
# 59 tensor(0.4824, grad_fn=<NegBackward>)
# 60 tensor(0.2990, grad_fn=<NegBackward>)
# 61 tensor(0.3622, grad_fn=<NegBackward>)
# 62 tensor(0.4561, grad_fn=<NegBackward>)
# 63 tensor(0.5288, grad_fn=<NegBackward>)
# 64 tensor(0.5195, grad_fn=<NegBackward>)
# 65 tensor(0.4333, grad_fn=<NegBackward>)
# 66 tensor(0.4596, grad_fn=<NegBackward>)
# 67 tensor(0.4488, grad_fn=<NegBackward>)
# 68 tensor(0.4099, grad_fn=<NegBackward>)
# 69 tensor(0.3776, grad_fn=<NegBackward>)
# 70 tensor(0.3579, grad_fn=<NegBackward>)
# 71 tensor(0.2228, grad_fn=<NegBackward>)
# 72 tensor(0.4498, grad_fn=<NegBackward>)
# 73 tensor(0.4410, grad_fn=<NegBackward>)
# 74 tensor(0.5052, grad_fn=<NegBackward>)
# 75 tensor(0.4891, grad_fn=<NegBackward>)
# 76 tensor(0.3062, grad_fn=<NegBackward>)
# 77 tensor(0.5673, grad_fn=<NegBackward>)
# 78 tensor(0.3866, grad_fn=<NegBackward>)
# 79 tensor(0.4456, grad_fn=<NegBackward>)
# 80 tensor(0.7713, grad_fn=<NegBackward>)
# 81 tensor(0.2907, grad_fn=<NegBackward>)
# 82 tensor(0.4893, grad_fn=<NegBackward>)
# 83 tensor(0.3989, grad_fn=<NegBackward>)
# 84 tensor(0.3155, grad_fn=<NegBackward>)
# 85 tensor(0.2380, grad_fn=<NegBackward>)
# 86 tensor(0.5043, grad_fn=<NegBackward>)
# 87 tensor(0.3804, grad_fn=<NegBackward>)
# 88 tensor(0.3590, grad_fn=<NegBackward>)
# 89 tensor(0.4134, grad_fn=<NegBackward>)
# 90 tensor(0.2974, grad_fn=<NegBackward>)
# 91 tensor(0.4854, grad_fn=<NegBackward>)
# 92 tensor(0.3659, grad_fn=<NegBackward>)
# 93 tensor(0.3325, grad_fn=<NegBackward>)
# 94 tensor(0.2444, grad_fn=<NegBackward>)
# 95 tensor(0.4010, grad_fn=<NegBackward>)
# 96 tensor(0.3136, grad_fn=<NegBackward>)
# 97 tensor(0.3430, grad_fn=<NegBackward>)
# 98 tensor(0.2894, grad_fn=<NegBackward>)
# 99 tensor(0.2718, grad_fn=<NegBackward>)
# 100 tensor(0.3131, grad_fn=<NegBackward>)
# 101 tensor(0.5113, grad_fn=<NegBackward>)
# 102 tensor(0.2515, grad_fn=<NegBackward>)
# 103 tensor(0.3143, grad_fn=<NegBackward>)
# 104 tensor(0.3216, grad_fn=<NegBackward>)
# 105 tensor(0.2670, grad_fn=<NegBackward>)
# 106 tensor(0.5090, grad_fn=<NegBackward>)
# 107 tensor(0.4490, grad_fn=<NegBackward>)
# 108 tensor(0.5897, grad_fn=<NegBackward>)
# 109 tensor(0.6848, grad_fn=<NegBackward>)
# 110 tensor(0.2971, grad_fn=<NegBackward>)
# 111 tensor(0.4471, grad_fn=<NegBackward>)
# 112 tensor(0.4937, grad_fn=<NegBackward>)
# 113 tensor(0.6564, grad_fn=<NegBackward>)
# 114 tensor(0.5753, grad_fn=<NegBackward>)
# 115 tensor(0.3145, grad_fn=<NegBackward>)
# 116 tensor(0.3428, grad_fn=<NegBackward>)
# 117 tensor(0.4238, grad_fn=<NegBackward>)
# 118 tensor(0.2471, grad_fn=<NegBackward>)
# 119 tensor(0.4931, grad_fn=<NegBackward>)
# 120 tensor(0.3548, grad_fn=<NegBackward>)
# 121 tensor(0.4129, grad_fn=<NegBackward>)
# 122 tensor(0.5388, grad_fn=<NegBackward>)
# 123 tensor(0.5134, grad_fn=<NegBackward>)
# 124 tensor(0.3827, grad_fn=<NegBackward>)
# 125 tensor(0.3278, grad_fn=<NegBackward>)
# 126 tensor(0.5205, grad_fn=<NegBackward>)
# 127 tensor(0.2448, grad_fn=<NegBackward>)
# 128 tensor(0.6698, grad_fn=<NegBackward>)
# 129 tensor(0.4579, grad_fn=<NegBackward>)
# 130 tensor(0.2594, grad_fn=<NegBackward>)
# 131 tensor(0.4419, grad_fn=<NegBackward>)
# 132 tensor(0.5095, grad_fn=<NegBackward>)
# 133 tensor(0.2946, grad_fn=<NegBackward>)
# 134 tensor(0.3446, grad_fn=<NegBackward>)
# 135 tensor(0.6967, grad_fn=<NegBackward>)
# 136 tensor(0.8372, grad_fn=<NegBackward>)
# 137 tensor(0.5748, grad_fn=<NegBackward>)
# 138 tensor(0.7383, grad_fn=<NegBackward>)
# 139 tensor(0.5261, grad_fn=<NegBackward>)
# 140 tensor(0.3165, grad_fn=<NegBackward>)
# 141 tensor(0.2013, grad_fn=<NegBackward>)
# 142 tensor(0.4916, grad_fn=<NegBackward>)
# 143 tensor(0.2436, grad_fn=<NegBackward>)
# 144 tensor(0.4965, grad_fn=<NegBackward>)
# 145 tensor(0.4162, grad_fn=<NegBackward>)
# 146 tensor(0.4834, grad_fn=<NegBackward>)
# 147 tensor(0.5934, grad_fn=<NegBackward>)
# 148 tensor(0.3107, grad_fn=<NegBackward>)
# 149 tensor(0.3883, grad_fn=<NegBackward>)
# 150 tensor(0.2798, grad_fn=<NegBackward>)
# 151 tensor(0.1983, grad_fn=<NegBackward>)
# 152 tensor(0.5752, grad_fn=<NegBackward>)
# 153 tensor(0.2128, grad_fn=<NegBackward>)
# 154 tensor(0.2538, grad_fn=<NegBackward>)
# 155 tensor(0.3306, grad_fn=<NegBackward>)
# 156 tensor(0.3947, grad_fn=<NegBackward>)
# 157 tensor(0.2559, grad_fn=<NegBackward>)
# 158 tensor(0.2652, grad_fn=<NegBackward>)
# 159 tensor(0.4496, grad_fn=<NegBackward>)
# 160 tensor(0.3659, grad_fn=<NegBackward>)
# 161 tensor(0.2209, grad_fn=<NegBackward>)
# 162 tensor(0.2365, grad_fn=<NegBackward>)
# 163 tensor(0.3105, grad_fn=<NegBackward>)
# 164 tensor(0.1488, grad_fn=<NegBackward>)
# 165 tensor(0.1914, grad_fn=<NegBackward>)
# 166 tensor(0.3178, grad_fn=<NegBackward>)
# 167 tensor(0.4328, grad_fn=<NegBackward>)
# 168 tensor(0.3721, grad_fn=<NegBackward>)
# 169 tensor(0.2860, grad_fn=<NegBackward>)
# 170 tensor(0.2752, grad_fn=<NegBackward>)
# 171 tensor(0.3108, grad_fn=<NegBackward>)
# 172 tensor(0.2579, grad_fn=<NegBackward>)
# 173 tensor(0.2922, grad_fn=<NegBackward>)
# 174 tensor(0.1952, grad_fn=<NegBackward>)
# 175 tensor(0.4580, grad_fn=<NegBackward>)
# 176 tensor(0.1971, grad_fn=<NegBackward>)
# 177 tensor(0.2848, grad_fn=<NegBackward>)
# 178 tensor(0.2563, grad_fn=<NegBackward>)
# 179 tensor(0.3158, grad_fn=<NegBackward>)
# 180 tensor(0.6406, grad_fn=<NegBackward>)
# 181 tensor(0.4924, grad_fn=<NegBackward>)
# 182 tensor(0.5643, grad_fn=<NegBackward>)
# 183 tensor(0.4515, grad_fn=<NegBackward>)
# 184 tensor(0.2798, grad_fn=<NegBackward>)
# 185 tensor(0.3894, grad_fn=<NegBackward>)
# 186 tensor(0.2827, grad_fn=<NegBackward>)
# 187 tensor(0.2817, grad_fn=<NegBackward>)
# 188 tensor(0.3844, grad_fn=<NegBackward>)
# 189 tensor(0.2695, grad_fn=<NegBackward>)
# 190 tensor(0.4600, grad_fn=<NegBackward>)
# 191 tensor(0.3936, grad_fn=<NegBackward>)
# 192 tensor(0.3854, grad_fn=<NegBackward>)
# 193 tensor(0.4372, grad_fn=<NegBackward>)
# 194 tensor(0.3981, grad_fn=<NegBackward>)
# 195 tensor(0.4523, grad_fn=<NegBackward>)
# 196 tensor(0.6743, grad_fn=<NegBackward>)
# 197 tensor(0.7462, grad_fn=<NegBackward>)
# 198 tensor(0.5757, grad_fn=<NegBackward>)
# 199 tensor(0.4545, grad_fn=<NegBackward>)
# 200 tensor(0.2939, grad_fn=<NegBackward>)
# 201 tensor(0.3000, grad_fn=<NegBackward>)
# 202 tensor(0.5856, grad_fn=<NegBackward>)
# 203 tensor(0.6372, grad_fn=<NegBackward>)
# 204 tensor(0.5754, grad_fn=<NegBackward>)
# 205 tensor(0.5076, grad_fn=<NegBackward>)
# 206 tensor(0.3317, grad_fn=<NegBackward>)
# 207 tensor(0.3418, grad_fn=<NegBackward>)
# 208 tensor(0.3782, grad_fn=<NegBackward>)
# 209 tensor(0.3239, grad_fn=<NegBackward>)
# 210 tensor(0.2344, grad_fn=<NegBackward>)
# 211 tensor(0.4370, grad_fn=<NegBackward>)
# 212 tensor(0.1687, grad_fn=<NegBackward>)
# 213 tensor(0.5413, grad_fn=<NegBackward>)
# 214 tensor(0.5198, grad_fn=<NegBackward>)
# 215 tensor(0.2721, grad_fn=<NegBackward>)
# 216 tensor(0.4116, grad_fn=<NegBackward>)
# 217 tensor(0.4595, grad_fn=<NegBackward>)
# 218 tensor(0.6650, grad_fn=<NegBackward>)
# 219 tensor(0.5254, grad_fn=<NegBackward>)
# 220 tensor(0.4562, grad_fn=<NegBackward>)
# 221 tensor(0.4309, grad_fn=<NegBackward>)
# 222 tensor(0.4253, grad_fn=<NegBackward>)
# 223 tensor(0.5418, grad_fn=<NegBackward>)
# 224 tensor(0.7395, grad_fn=<NegBackward>)
# 225 tensor(0.3792, grad_fn=<NegBackward>)
# 226 tensor(0.3713, grad_fn=<NegBackward>)
# 227 tensor(0.4894, grad_fn=<NegBackward>)
# 228 tensor(0.4991, grad_fn=<NegBackward>)
# 229 tensor(0.5248, grad_fn=<NegBackward>)
# 230 tensor(0.5931, grad_fn=<NegBackward>)
# 231 tensor(0.6784, grad_fn=<NegBackward>)
# 232 tensor(0.3335, grad_fn=<NegBackward>)
# 233 tensor(0.2506, grad_fn=<NegBackward>)
# 234 tensor(0.2518, grad_fn=<NegBackward>)
# 235 tensor(0.2442, grad_fn=<NegBackward>)
# 236 tensor(0.5725, grad_fn=<NegBackward>)
# 237 tensor(0.3716, grad_fn=<NegBackward>)
# 238 tensor(0.3722, grad_fn=<NegBackward>)
# 239 tensor(0.2684, grad_fn=<NegBackward>)
# 240 tensor(0.2660, grad_fn=<NegBackward>)
# 241 tensor(0.2909, grad_fn=<NegBackward>)
# 242 tensor(0.4105, grad_fn=<NegBackward>)
# 243 tensor(0.3242, grad_fn=<NegBackward>)
# 244 tensor(0.2583, grad_fn=<NegBackward>)
# 245 tensor(0.4383, grad_fn=<NegBackward>)
# 246 tensor(0.4302, grad_fn=<NegBackward>)
# 247 tensor(0.3799, grad_fn=<NegBackward>)
# 248 tensor(0.3757, grad_fn=<NegBackward>)
# 249 tensor(0.6715, grad_fn=<NegBackward>)
# 250 tensor(0.5635, grad_fn=<NegBackward>)
# 251 tensor(0.3054, grad_fn=<NegBackward>)
# 252 tensor(0.2106, grad_fn=<NegBackward>)
# 253 tensor(0.3361, grad_fn=<NegBackward>)
# 254 tensor(0.3280, grad_fn=<NegBackward>)
# 255 tensor(0.3239, grad_fn=<NegBackward>)
# 256 tensor(0.2492, grad_fn=<NegBackward>)
# 257 tensor(0.3448, grad_fn=<NegBackward>)
# 258 tensor(0.4632, grad_fn=<NegBackward>)
# 259 tensor(0.3463, grad_fn=<NegBackward>)
# 260 tensor(0.4464, grad_fn=<NegBackward>)
# 261 tensor(0.3565, grad_fn=<NegBackward>)
# 262 tensor(0.4376, grad_fn=<NegBackward>)
# 263 tensor(0.3266, grad_fn=<NegBackward>)
# 264 tensor(0.3496, grad_fn=<NegBackward>)
# 265 tensor(0.4324, grad_fn=<NegBackward>)
# 266 tensor(0.3873, grad_fn=<NegBackward>)
# 267 tensor(0.3606, grad_fn=<NegBackward>)
# 268 tensor(0.4417, grad_fn=<NegBackward>)
# 269 tensor(0.4346, grad_fn=<NegBackward>)
# 270 tensor(0.2221, grad_fn=<NegBackward>)
# 271 tensor(0.3638, grad_fn=<NegBackward>)
# 272 tensor(0.2858, grad_fn=<NegBackward>)
# 273 tensor(0.4774, grad_fn=<NegBackward>)
# 274 tensor(0.6602, grad_fn=<NegBackward>)
# 275 tensor(0.3175, grad_fn=<NegBackward>)
# 276 tensor(0.4736, grad_fn=<NegBackward>)
# 277 tensor(0.3580, grad_fn=<NegBackward>)
# 278 tensor(0.5659, grad_fn=<NegBackward>)
# 279 tensor(0.3467, grad_fn=<NegBackward>)
# 280 tensor(0.2710, grad_fn=<NegBackward>)
# 281 tensor(0.3063, grad_fn=<NegBackward>)
# 282 tensor(0.3047, grad_fn=<NegBackward>)
# 283 tensor(0.2094, grad_fn=<NegBackward>)
# 284 tensor(0.2037, grad_fn=<NegBackward>)
# 285 tensor(0.2568, grad_fn=<NegBackward>)
# 286 tensor(0.2847, grad_fn=<NegBackward>)
# 287 tensor(0.3304, grad_fn=<NegBackward>)
# 288 tensor(0.3476, grad_fn=<NegBackward>)
# 289 tensor(0.2450, grad_fn=<NegBackward>)
# 290 tensor(0.4605, grad_fn=<NegBackward>)
# 291 tensor(0.2782, grad_fn=<NegBackward>)
# 292 tensor(0.3770, grad_fn=<NegBackward>)
# 293 tensor(0.1843, grad_fn=<NegBackward>)
# 294 tensor(0.3493, grad_fn=<NegBackward>)
# 295 tensor(0.2075, grad_fn=<NegBackward>)
# 296 tensor(0.2292, grad_fn=<NegBackward>)
# 297 tensor(0.3746, grad_fn=<NegBackward>)
# 298 tensor(0.3583, grad_fn=<NegBackward>)
# 299 tensor(0.2897, grad_fn=<NegBackward>)
# 300 tensor(0.3869, grad_fn=<NegBackward>)
# 301 tensor(0.3338, grad_fn=<NegBackward>)
# 302 tensor(0.3569, grad_fn=<NegBackward>)
# 303 tensor(0.3637, grad_fn=<NegBackward>)
# 304 tensor(0.3423, grad_fn=<NegBackward>)
# 305 tensor(0.3995, grad_fn=<NegBackward>)
# 306 tensor(0.2631, grad_fn=<NegBackward>)
# 307 tensor(0.1669, grad_fn=<NegBackward>)
# 308 tensor(0.1062, grad_fn=<NegBackward>)
# 309 tensor(0.4479, grad_fn=<NegBackward>)
# 310 tensor(0.2314, grad_fn=<NegBackward>)
# 311 tensor(0.3993, grad_fn=<NegBackward>)
# 312 tensor(0.4356, grad_fn=<NegBackward>)
# 313 tensor(0.4087, grad_fn=<NegBackward>)
# 314 tensor(0.2626, grad_fn=<NegBackward>)
# 315 tensor(0.5986, grad_fn=<NegBackward>)
# 316 tensor(0.2591, grad_fn=<NegBackward>)
# 317 tensor(0.3145, grad_fn=<NegBackward>)
# 318 tensor(0.1918, grad_fn=<NegBackward>)
# 319 tensor(0.2379, grad_fn=<NegBackward>)
# 320 tensor(0.2213, grad_fn=<NegBackward>)
# 321 tensor(0.4876, grad_fn=<NegBackward>)
# 322 tensor(0.2915, grad_fn=<NegBackward>)
# 323 tensor(0.4955, grad_fn=<NegBackward>)
# 324 tensor(0.3630, grad_fn=<NegBackward>)
# 325 tensor(0.4467, grad_fn=<NegBackward>)
# 326 tensor(0.5795, grad_fn=<NegBackward>)
# 327 tensor(0.7048, grad_fn=<NegBackward>)
# 328 tensor(0.4474, grad_fn=<NegBackward>)
# 329 tensor(0.3809, grad_fn=<NegBackward>)
# 330 tensor(0.3167, grad_fn=<NegBackward>)
# 331 tensor(0.3168, grad_fn=<NegBackward>)
# 332 tensor(0.2182, grad_fn=<NegBackward>)
# 333 tensor(0.3075, grad_fn=<NegBackward>)
# 334 tensor(0.3835, grad_fn=<NegBackward>)
# 335 tensor(0.1380, grad_fn=<NegBackward>)
# 336 tensor(0.2554, grad_fn=<NegBackward>)
# 337 tensor(0.5639, grad_fn=<NegBackward>)
# 338 tensor(0.2681, grad_fn=<NegBackward>)
# 339 tensor(0.2857, grad_fn=<NegBackward>)
# 340 tensor(0.1013, grad_fn=<NegBackward>)
# 341 tensor(0.1476, grad_fn=<NegBackward>)
# 342 tensor(0.3149, grad_fn=<NegBackward>)
# 343 tensor(0.3452, grad_fn=<NegBackward>)
# 344 tensor(0.1655, grad_fn=<NegBackward>)
# 345 tensor(0.4523, grad_fn=<NegBackward>)
# 346 tensor(0.4575, grad_fn=<NegBackward>)
# 347 tensor(0.4658, grad_fn=<NegBackward>)
# 348 tensor(0.3377, grad_fn=<NegBackward>)
# 349 tensor(0.1085, grad_fn=<NegBackward>)
# 350 tensor(0.3117, grad_fn=<NegBackward>)
# 351 tensor(0.6537, grad_fn=<NegBackward>)
# 352 tensor(0.7884, grad_fn=<NegBackward>)
# 353 tensor(0.5158, grad_fn=<NegBackward>)
# 354 tensor(0.3251, grad_fn=<NegBackward>)
# 355 tensor(0.3450, grad_fn=<NegBackward>)
# 356 tensor(0.3166, grad_fn=<NegBackward>)
# 357 tensor(0.2216, grad_fn=<NegBackward>)
# 358 tensor(0.1330, grad_fn=<NegBackward>)
# 359 tensor(0.2718, grad_fn=<NegBackward>)
# 360 tensor(0.4466, grad_fn=<NegBackward>)
# 361 tensor(0.3642, grad_fn=<NegBackward>)
# 362 tensor(0.3554, grad_fn=<NegBackward>)
# 363 tensor(0.1733, grad_fn=<NegBackward>)
# 364 tensor(0.2660, grad_fn=<NegBackward>)
# 365 tensor(0.2611, grad_fn=<NegBackward>)
# 366 tensor(0.3341, grad_fn=<NegBackward>)
# 367 tensor(0.2921, grad_fn=<NegBackward>)
# 368 tensor(0.2676, grad_fn=<NegBackward>)
# 369 tensor(0.3042, grad_fn=<NegBackward>)
# 370 tensor(0.5899, grad_fn=<NegBackward>)
# 371 tensor(0.2377, grad_fn=<NegBackward>)
# 372 tensor(0.4258, grad_fn=<NegBackward>)
# 373 tensor(0.3394, grad_fn=<NegBackward>)
# 374 tensor(0.4642, grad_fn=<NegBackward>)
# 375 tensor(0.3927, grad_fn=<NegBackward>)
# 376 tensor(0.2436, grad_fn=<NegBackward>)
# 377 tensor(0.2272, grad_fn=<NegBackward>)
# 378 tensor(0.3995, grad_fn=<NegBackward>)
# 379 tensor(0.4685, grad_fn=<NegBackward>)
# 380 tensor(0.2440, grad_fn=<NegBackward>)
# 381 tensor(0.2805, grad_fn=<NegBackward>)
# 382 tensor(0.3754, grad_fn=<NegBackward>)
# 383 tensor(0.4491, grad_fn=<NegBackward>)
# 384 tensor(0.3729, grad_fn=<NegBackward>)
# 385 tensor(0.4133, grad_fn=<NegBackward>)
# 386 tensor(0.3793, grad_fn=<NegBackward>)
# 387 tensor(0.5247, grad_fn=<NegBackward>)
# 388 tensor(0.3057, grad_fn=<NegBackward>)
# 389 tensor(0.3996, grad_fn=<NegBackward>)
# 390 tensor(0.3602, grad_fn=<NegBackward>)
# 391 tensor(0.1526, grad_fn=<NegBackward>)
# 392 tensor(0.3475, grad_fn=<NegBackward>)
# 393 tensor(0.3153, grad_fn=<NegBackward>)
# 394 tensor(0.2928, grad_fn=<NegBackward>)
# 395 tensor(0.5085, grad_fn=<NegBackward>)
# 396 tensor(0.1270, grad_fn=<NegBackward>)
# 397 tensor(0.1249, grad_fn=<NegBackward>)
# 398 tensor(0.2383, grad_fn=<NegBackward>)
# 399 tensor(0.3610, grad_fn=<NegBackward>)
# 400 tensor(0.2288, grad_fn=<NegBackward>)
# 401 tensor(0.2427, grad_fn=<NegBackward>)
# 402 tensor(0.2648, grad_fn=<NegBackward>)
# 403 tensor(0.4233, grad_fn=<NegBackward>)
# 404 tensor(0.2013, grad_fn=<NegBackward>)
# 405 tensor(0.2778, grad_fn=<NegBackward>)
# 406 tensor(0.2299, grad_fn=<NegBackward>)
# 407 tensor(0.2582, grad_fn=<NegBackward>)
# 408 tensor(0.2181, grad_fn=<NegBackward>)
# 409 tensor(0.2193, grad_fn=<NegBackward>)
# 410 tensor(0.3517, grad_fn=<NegBackward>)
# 411 tensor(0.3105, grad_fn=<NegBackward>)
# 412 tensor(0.5925, grad_fn=<NegBackward>)
# 413 tensor(0.4279, grad_fn=<NegBackward>)
# 414 tensor(0.3588, grad_fn=<NegBackward>)
# 415 tensor(0.3869, grad_fn=<NegBackward>)
# 416 tensor(0.6252, grad_fn=<NegBackward>)
# 417 tensor(0.6299, grad_fn=<NegBackward>)
# 418 tensor(0.3775, grad_fn=<NegBackward>)
# 419 tensor(0.4181, grad_fn=<NegBackward>)
# 420 tensor(0.5090, grad_fn=<NegBackward>)
# 421 tensor(0.1426, grad_fn=<NegBackward>)
# 422 tensor(0.1922, grad_fn=<NegBackward>)
# 423 tensor(0.2623, grad_fn=<NegBackward>)
# 424 tensor(0.6967, grad_fn=<NegBackward>)
# 425 tensor(0.3689, grad_fn=<NegBackward>)
# 426 tensor(0.1971, grad_fn=<NegBackward>)
# 427 tensor(0.3144, grad_fn=<NegBackward>)
# 428 tensor(0.3408, grad_fn=<NegBackward>)
# 429 tensor(0.4318, grad_fn=<NegBackward>)
# 430 tensor(0.2235, grad_fn=<NegBackward>)
# 431 tensor(0.3829, grad_fn=<NegBackward>)
# 432 tensor(0.3089, grad_fn=<NegBackward>)
# 433 tensor(0.2544, grad_fn=<NegBackward>)
# 434 tensor(0.3779, grad_fn=<NegBackward>)
# 435 tensor(0.2338, grad_fn=<NegBackward>)
# 436 tensor(0.2028, grad_fn=<NegBackward>)
# 437 tensor(0.2273, grad_fn=<NegBackward>)
# 438 tensor(0.1846, grad_fn=<NegBackward>)
# 439 tensor(0.3272, grad_fn=<NegBackward>)
# 440 tensor(0.3203, grad_fn=<NegBackward>)
# 441 tensor(0.2481, grad_fn=<NegBackward>)
# 442 tensor(0.1571, grad_fn=<NegBackward>)
# 443 tensor(0.7057, grad_fn=<NegBackward>)
# 444 tensor(0.2433, grad_fn=<NegBackward>)
# 445 tensor(0.3542, grad_fn=<NegBackward>)
# 446 tensor(0.3102, grad_fn=<NegBackward>)
# 447 tensor(0.9267, grad_fn=<NegBackward>)
# 448 tensor(0.3140, grad_fn=<NegBackward>)
# 449 tensor(0.2730, grad_fn=<NegBackward>)
# 450 tensor(0.2137, grad_fn=<NegBackward>)
# 451 tensor(0.1566, grad_fn=<NegBackward>)
# 452 tensor(0.3206, grad_fn=<NegBackward>)
# 453 tensor(0.1572, grad_fn=<NegBackward>)
# 454 tensor(0.4317, grad_fn=<NegBackward>)
# 455 tensor(0.4990, grad_fn=<NegBackward>)
# 456 tensor(0.4298, grad_fn=<NegBackward>)
# 457 tensor(0.3461, grad_fn=<NegBackward>)
# 458 tensor(0.3129, grad_fn=<NegBackward>)
# 459 tensor(0.3366, grad_fn=<NegBackward>)
# 460 tensor(0.2447, grad_fn=<NegBackward>)
# 461 tensor(0.2585, grad_fn=<NegBackward>)
# 462 tensor(0.2776, grad_fn=<NegBackward>)
# 463 tensor(0.3430, grad_fn=<NegBackward>)
# 464 tensor(0.4967, grad_fn=<NegBackward>)
# 465 tensor(0.2478, grad_fn=<NegBackward>)
# 466 tensor(0.5926, grad_fn=<NegBackward>)
# 467 tensor(0.5169, grad_fn=<NegBackward>)
# 468 tensor(0.4677, grad_fn=<NegBackward>)
# 469 tensor(0.3692, grad_fn=<NegBackward>)
# 470 tensor(0.4073, grad_fn=<NegBackward>)
# 471 tensor(0.4904, grad_fn=<NegBackward>)
# 472 tensor(0.4187, grad_fn=<NegBackward>)
# 473 tensor(0.2481, grad_fn=<NegBackward>)
# 474 tensor(0.1905, grad_fn=<NegBackward>)
# 475 tensor(0.3175, grad_fn=<NegBackward>)
# 476 tensor(0.4094, grad_fn=<NegBackward>)
# 477 tensor(0.2968, grad_fn=<NegBackward>)
# 478 tensor(0.4812, grad_fn=<NegBackward>)
# 479 tensor(0.4015, grad_fn=<NegBackward>)
# 480 tensor(0.3758, grad_fn=<NegBackward>)
# 481 tensor(0.3307, grad_fn=<NegBackward>)
# 482 tensor(0.4739, grad_fn=<NegBackward>)
# 483 tensor(0.2787, grad_fn=<NegBackward>)
# 484 tensor(0.4367, grad_fn=<NegBackward>)
# 485 tensor(0.3210, grad_fn=<NegBackward>)
# 486 tensor(0.5132, grad_fn=<NegBackward>)
# 487 tensor(0.5842, grad_fn=<NegBackward>)
# 488 tensor(0.4068, grad_fn=<NegBackward>)
# 489 tensor(0.7683, grad_fn=<NegBackward>)
# 490 tensor(0.5869, grad_fn=<NegBackward>)
# 491 tensor(0.3973, grad_fn=<NegBackward>)
# 492 tensor(0.1731, grad_fn=<NegBackward>)
# 493 tensor(0.3148, grad_fn=<NegBackward>)
# 494 tensor(0.4946, grad_fn=<NegBackward>)
# 495 tensor(0.6412, grad_fn=<NegBackward>)
# 496 tensor(0.4299, grad_fn=<NegBackward>)
# 497 tensor(0.2940, grad_fn=<NegBackward>)
# 498 tensor(0.3026, grad_fn=<NegBackward>)
# 499 tensor(0.3623, grad_fn=<NegBackward>)
# 500 tensor(0.3825, grad_fn=<NegBackward>)
# 501 tensor(0.3829, grad_fn=<NegBackward>)
# 502 tensor(0.4666, grad_fn=<NegBackward>)
# 503 tensor(0.3674, grad_fn=<NegBackward>)
# 504 tensor(0.4970, grad_fn=<NegBackward>)
# 505 tensor(0.4868, grad_fn=<NegBackward>)
# 506 tensor(0.4762, grad_fn=<NegBackward>)
# 507 tensor(0.4853, grad_fn=<NegBackward>)
# 508 tensor(0.2668, grad_fn=<NegBackward>)
# 509 tensor(0.1313, grad_fn=<NegBackward>)
# 510 tensor(0.4476, grad_fn=<NegBackward>)
# 511 tensor(0.3043, grad_fn=<NegBackward>)
# 512 tensor(0.5666, grad_fn=<NegBackward>)
# 513 tensor(0.2712, grad_fn=<NegBackward>)
# 514 tensor(0.3666, grad_fn=<NegBackward>)
# 515 tensor(0.2650, grad_fn=<NegBackward>)
# 516 tensor(0.2754, grad_fn=<NegBackward>)
# 517 tensor(0.2286, grad_fn=<NegBackward>)
# 518 tensor(0.2265, grad_fn=<NegBackward>)
# 519 tensor(0.3242, grad_fn=<NegBackward>)
# 520 tensor(0.3884, grad_fn=<NegBackward>)
# 521 tensor(0.4207, grad_fn=<NegBackward>)
# 522 tensor(0.3631, grad_fn=<NegBackward>)
# 523 tensor(0.3144, grad_fn=<NegBackward>)
# 524 tensor(0.2848, grad_fn=<NegBackward>)
# 525 tensor(0.1806, grad_fn=<NegBackward>)
# 526 tensor(0.1812, grad_fn=<NegBackward>)
# 527 tensor(0.3920, grad_fn=<NegBackward>)
# 528 tensor(0.1559, grad_fn=<NegBackward>)
# 529 tensor(0.1013, grad_fn=<NegBackward>)
# 530 tensor(0.1644, grad_fn=<NegBackward>)
# 531 tensor(0.1901, grad_fn=<NegBackward>)
# 532 tensor(0.2757, grad_fn=<NegBackward>)
# 533 tensor(0.1966, grad_fn=<NegBackward>)
# 534 tensor(0.2280, grad_fn=<NegBackward>)
# 535 tensor(0.2060, grad_fn=<NegBackward>)
# 536 tensor(0.2021, grad_fn=<NegBackward>)
# 537 tensor(0.3203, grad_fn=<NegBackward>)
# 538 tensor(0.4753, grad_fn=<NegBackward>)
# 539 tensor(0.5291, grad_fn=<NegBackward>)
# 540 tensor(0.3348, grad_fn=<NegBackward>)
# 541 tensor(0.4785, grad_fn=<NegBackward>)
# 542 tensor(0.4310, grad_fn=<NegBackward>)
# 543 tensor(0.3708, grad_fn=<NegBackward>)
# 544 tensor(0.5332, grad_fn=<NegBackward>)
# 545 tensor(0.3304, grad_fn=<NegBackward>)
# 546 tensor(0.1788, grad_fn=<NegBackward>)
# 547 tensor(0.2996, grad_fn=<NegBackward>)
# 548 tensor(0.1903, grad_fn=<NegBackward>)
# 549 tensor(0.2821, grad_fn=<NegBackward>)
# 550 tensor(0.3655, grad_fn=<NegBackward>)
# 551 tensor(0.2106, grad_fn=<NegBackward>)
# 552 tensor(0.2090, grad_fn=<NegBackward>)
# 553 tensor(0.3169, grad_fn=<NegBackward>)
# 554 tensor(0.4822, grad_fn=<NegBackward>)
# 555 tensor(0.1871, grad_fn=<NegBackward>)
# 556 tensor(0.3278, grad_fn=<NegBackward>)
# 557 tensor(0.2719, grad_fn=<NegBackward>)
# 558 tensor(0.1844, grad_fn=<NegBackward>)
# 559 tensor(0.1650, grad_fn=<NegBackward>)
# 560 tensor(0.2841, grad_fn=<NegBackward>)
# 561 tensor(0.3113, grad_fn=<NegBackward>)
# 562 tensor(0.3940, grad_fn=<NegBackward>)
# 563 tensor(0.3812, grad_fn=<NegBackward>)
# 564 tensor(0.3048, grad_fn=<NegBackward>)
# 565 tensor(0.2717, grad_fn=<NegBackward>)
# 566 tensor(0.2375, grad_fn=<NegBackward>)
# 567 tensor(0.1178, grad_fn=<NegBackward>)
# 568 tensor(0.3053, grad_fn=<NegBackward>)
# 569 tensor(0.3922, grad_fn=<NegBackward>)
# 570 tensor(0.1911, grad_fn=<NegBackward>)
# 571 tensor(0.2625, grad_fn=<NegBackward>)
# 572 tensor(0.1539, grad_fn=<NegBackward>)
# 573 tensor(0.1937, grad_fn=<NegBackward>)
# 574 tensor(0.3367, grad_fn=<NegBackward>)
# 575 tensor(0.2991, grad_fn=<NegBackward>)
# 576 tensor(0.3120, grad_fn=<NegBackward>)
# 577 tensor(0.1766, grad_fn=<NegBackward>)
# 578 tensor(0.3042, grad_fn=<NegBackward>)
# 579 tensor(0.4598, grad_fn=<NegBackward>)
# 580 tensor(0.4271, grad_fn=<NegBackward>)
# 581 tensor(0.2660, grad_fn=<NegBackward>)
# 582 tensor(0.6361, grad_fn=<NegBackward>)
# 583 tensor(0.7114, grad_fn=<NegBackward>)
# 584 tensor(0.9334, grad_fn=<NegBackward>)
# 585 tensor(0.5377, grad_fn=<NegBackward>)
# 586 tensor(0.5336, grad_fn=<NegBackward>)
# 587 tensor(0.2640, grad_fn=<NegBackward>)
# 588 tensor(0.2750, grad_fn=<NegBackward>)
# 589 tensor(0.5052, grad_fn=<NegBackward>)
# 590 tensor(0.2936, grad_fn=<NegBackward>)
# 591 tensor(0.3504, grad_fn=<NegBackward>)
# 592 tensor(0.2817, grad_fn=<NegBackward>)
# 593 tensor(0.4078, grad_fn=<NegBackward>)
# 594 tensor(0.3166, grad_fn=<NegBackward>)
# 595 tensor(0.2246, grad_fn=<NegBackward>)
# 596 tensor(0.1969, grad_fn=<NegBackward>)
# 597 tensor(0.4221, grad_fn=<NegBackward>)
# 598 tensor(0.3352, grad_fn=<NegBackward>)
# 599 tensor(0.3414, grad_fn=<NegBackward>)
# 600 tensor(0.2617, grad_fn=<NegBackward>)
# 601 tensor(0.3660, grad_fn=<NegBackward>)
# 602 tensor(0.4257, grad_fn=<NegBackward>)
# 603 tensor(0.4877, grad_fn=<NegBackward>)
# 604 tensor(0.3444, grad_fn=<NegBackward>)
# 605 tensor(0.2999, grad_fn=<NegBackward>)
# 606 tensor(0.1838, grad_fn=<NegBackward>)
# 607 tensor(0.1794, grad_fn=<NegBackward>)
# 608 tensor(0.1909, grad_fn=<NegBackward>)
# 609 tensor(0.2442, grad_fn=<NegBackward>)
# 610 tensor(0.1592, grad_fn=<NegBackward>)
# 611 tensor(0.3029, grad_fn=<NegBackward>)
# 612 tensor(0.2450, grad_fn=<NegBackward>)
# 613 tensor(0.2852, grad_fn=<NegBackward>)
# 614 tensor(0.8300, grad_fn=<NegBackward>)
# 615 tensor(0.4036, grad_fn=<NegBackward>)
# 616 tensor(0.5528, grad_fn=<NegBackward>)
# 617 tensor(0.2806, grad_fn=<NegBackward>)
# 618 tensor(0.2630, grad_fn=<NegBackward>)
# 619 tensor(0.3382, grad_fn=<NegBackward>)
# 620 tensor(0.2894, grad_fn=<NegBackward>)
# 621 tensor(0.3851, grad_fn=<NegBackward>)
# 622 tensor(0.2540, grad_fn=<NegBackward>)
# 623 tensor(0.3206, grad_fn=<NegBackward>)
# 624 tensor(0.4679, grad_fn=<NegBackward>)
# 625 tensor(0.2400, grad_fn=<NegBackward>)
# 626 tensor(0.3538, grad_fn=<NegBackward>)
# 627 tensor(0.2991, grad_fn=<NegBackward>)
# 628 tensor(0.2144, grad_fn=<NegBackward>)
# 629 tensor(0.2843, grad_fn=<NegBackward>)
# 630 tensor(0.2924, grad_fn=<NegBackward>)
# 631 tensor(0.2349, grad_fn=<NegBackward>)
# 632 tensor(0.4044, grad_fn=<NegBackward>)
# 633 tensor(0.3377, grad_fn=<NegBackward>)
# 634 tensor(0.3078, grad_fn=<NegBackward>)
# 635 tensor(0.2987, grad_fn=<NegBackward>)
# 636 tensor(0.3703, grad_fn=<NegBackward>)
# 637 tensor(0.2073, grad_fn=<NegBackward>)
# 638 tensor(0.1819, grad_fn=<NegBackward>)
# 639 tensor(0.2168, grad_fn=<NegBackward>)
# 640 tensor(0.4840, grad_fn=<NegBackward>)
# 641 tensor(0.2490, grad_fn=<NegBackward>)
# 642 tensor(0.2979, grad_fn=<NegBackward>)
# 643 tensor(0.2297, grad_fn=<NegBackward>)
# 644 tensor(0.3567, grad_fn=<NegBackward>)
# 645 tensor(0.5357, grad_fn=<NegBackward>)
# 646 tensor(0.3241, grad_fn=<NegBackward>)
# 647 tensor(0.6373, grad_fn=<NegBackward>)
# 648 tensor(0.4154, grad_fn=<NegBackward>)
# 649 tensor(0.4710, grad_fn=<NegBackward>)
# 650 tensor(0.2311, grad_fn=<NegBackward>)
# 651 tensor(0.2211, grad_fn=<NegBackward>)
# 652 tensor(0.3194, grad_fn=<NegBackward>)
# 653 tensor(0.2312, grad_fn=<NegBackward>)
# 654 tensor(0.2130, grad_fn=<NegBackward>)
# 655 tensor(0.3448, grad_fn=<NegBackward>)
# 656 tensor(0.5247, grad_fn=<NegBackward>)
# 657 tensor(0.2730, grad_fn=<NegBackward>)
# 658 tensor(0.3479, grad_fn=<NegBackward>)
# 659 tensor(0.3457, grad_fn=<NegBackward>)
# 660 tensor(0.1637, grad_fn=<NegBackward>)
# 661 tensor(0.7215, grad_fn=<NegBackward>)
# 662 tensor(0.2495, grad_fn=<NegBackward>)
# 663 tensor(0.6498, grad_fn=<NegBackward>)
# 664 tensor(0.6219, grad_fn=<NegBackward>)
# 665 tensor(0.1610, grad_fn=<NegBackward>)
# 666 tensor(0.2736, grad_fn=<NegBackward>)
# 667 tensor(0.3453, grad_fn=<NegBackward>)
# 668 tensor(0.3687, grad_fn=<NegBackward>)
# 669 tensor(0.3845, grad_fn=<NegBackward>)
# 670 tensor(0.4784, grad_fn=<NegBackward>)
# 671 tensor(0.4522, grad_fn=<NegBackward>)
# 672 tensor(0.2920, grad_fn=<NegBackward>)
# 673 tensor(0.3546, grad_fn=<NegBackward>)
# 674 tensor(0.2797, grad_fn=<NegBackward>)
# 675 tensor(0.4651, grad_fn=<NegBackward>)
# 676 tensor(0.1181, grad_fn=<NegBackward>)
# 677 tensor(0.2238, grad_fn=<NegBackward>)
# 678 tensor(0.1651, grad_fn=<NegBackward>)
# 679 tensor(0.1735, grad_fn=<NegBackward>)
# 680 tensor(0.3494, grad_fn=<NegBackward>)
# 681 tensor(0.1653, grad_fn=<NegBackward>)
# 682 tensor(0.4182, grad_fn=<NegBackward>)
# 683 tensor(0.1518, grad_fn=<NegBackward>)
# 684 tensor(0.3339, grad_fn=<NegBackward>)
# 685 tensor(0.4318, grad_fn=<NegBackward>)
# 686 tensor(0.3965, grad_fn=<NegBackward>)
# 687 tensor(0.2629, grad_fn=<NegBackward>)
# 688 tensor(0.2565, grad_fn=<NegBackward>)
# 689 tensor(0.4454, grad_fn=<NegBackward>)
# 690 tensor(0.2108, grad_fn=<NegBackward>)
# 691 tensor(0.4062, grad_fn=<NegBackward>)
# 692 tensor(0.3965, grad_fn=<NegBackward>)
# 693 tensor(0.4154, grad_fn=<NegBackward>)
# 694 tensor(0.4790, grad_fn=<NegBackward>)
# 695 tensor(0.2899, grad_fn=<NegBackward>)
# 696 tensor(0.2219, grad_fn=<NegBackward>)
# 697 tensor(0.1624, grad_fn=<NegBackward>)
# 698 tensor(0.2082, grad_fn=<NegBackward>)
# 699 tensor(0.2759, grad_fn=<NegBackward>)
# 700 tensor(0.3846, grad_fn=<NegBackward>)
# 701 tensor(0.5198, grad_fn=<NegBackward>)
# 702 tensor(0.3311, grad_fn=<NegBackward>)
# 703 tensor(0.5157, grad_fn=<NegBackward>)
# 704 tensor(0.4895, grad_fn=<NegBackward>)
# 705 tensor(0.3764, grad_fn=<NegBackward>)
# 706 tensor(0.2831, grad_fn=<NegBackward>)
# 707 tensor(0.2425, grad_fn=<NegBackward>)
# 708 tensor(0.0996, grad_fn=<NegBackward>)
# 709 tensor(0.3693, grad_fn=<NegBackward>)
# 710 tensor(0.6446, grad_fn=<NegBackward>)
# 711 tensor(0.3387, grad_fn=<NegBackward>)
# 712 tensor(0.4475, grad_fn=<NegBackward>)
# 713 tensor(0.2740, grad_fn=<NegBackward>)
# 714 tensor(0.2279, grad_fn=<NegBackward>)
# 715 tensor(0.5182, grad_fn=<NegBackward>)
# 716 tensor(0.4041, grad_fn=<NegBackward>)
# 717 tensor(0.4057, grad_fn=<NegBackward>)
# 718 tensor(0.3609, grad_fn=<NegBackward>)
# 719 tensor(0.4117, grad_fn=<NegBackward>)
# 720 tensor(0.4679, grad_fn=<NegBackward>)
# 721 tensor(0.2860, grad_fn=<NegBackward>)
# 722 tensor(0.5135, grad_fn=<NegBackward>)
# 723 tensor(0.6449, grad_fn=<NegBackward>)
# 724 tensor(0.3878, grad_fn=<NegBackward>)
# 725 tensor(0.5061, grad_fn=<NegBackward>)
# 726 tensor(0.1639, grad_fn=<NegBackward>)
# 727 tensor(0.1684, grad_fn=<NegBackward>)
# 728 tensor(0.2836, grad_fn=<NegBackward>)
# 729 tensor(0.1371, grad_fn=<NegBackward>)
# 730 tensor(0.4271, grad_fn=<NegBackward>)
# 731 tensor(0.1067, grad_fn=<NegBackward>)
# 732 tensor(0.2191, grad_fn=<NegBackward>)
# 733 tensor(0.2571, grad_fn=<NegBackward>)
# 734 tensor(0.3195, grad_fn=<NegBackward>)
# 735 tensor(0.1957, grad_fn=<NegBackward>)
# 736 tensor(0.2412, grad_fn=<NegBackward>)
# 737 tensor(0.3131, grad_fn=<NegBackward>)
# 738 tensor(0.4370, grad_fn=<NegBackward>)
# 739 tensor(0.3560, grad_fn=<NegBackward>)
# 740 tensor(0.3228, grad_fn=<NegBackward>)
# 741 tensor(0.4100, grad_fn=<NegBackward>)
# 742 tensor(0.1651, grad_fn=<NegBackward>)
# 743 tensor(0.6291, grad_fn=<NegBackward>)
# 744 tensor(0.2325, grad_fn=<NegBackward>)
# 745 tensor(0.3781, grad_fn=<NegBackward>)
# 746 tensor(0.3642, grad_fn=<NegBackward>)
# 747 tensor(0.1762, grad_fn=<NegBackward>)
# 748 tensor(0.4024, grad_fn=<NegBackward>)
# 749 tensor(0.4449, grad_fn=<NegBackward>)
# 750 tensor(0.2164, grad_fn=<NegBackward>)
# 751 tensor(0.3033, grad_fn=<NegBackward>)
# 752 tensor(0.1352, grad_fn=<NegBackward>)
# 753 tensor(0.1400, grad_fn=<NegBackward>)
# 754 tensor(0.1972, grad_fn=<NegBackward>)
# 755 tensor(0.5995, grad_fn=<NegBackward>)
# 756 tensor(0.2612, grad_fn=<NegBackward>)
# 757 tensor(0.1691, grad_fn=<NegBackward>)
# 758 tensor(0.3286, grad_fn=<NegBackward>)
# 759 tensor(0.2240, grad_fn=<NegBackward>)
# 760 tensor(0.3127, grad_fn=<NegBackward>)
# 761 tensor(0.1687, grad_fn=<NegBackward>)
# 762 tensor(0.1770, grad_fn=<NegBackward>)
# 763 tensor(0.2484, grad_fn=<NegBackward>)
# 764 tensor(0.5753, grad_fn=<NegBackward>)
# 765 tensor(0.6607, grad_fn=<NegBackward>)
# 766 tensor(0.4606, grad_fn=<NegBackward>)
# 767 tensor(0.2632, grad_fn=<NegBackward>)
# 768 tensor(0.4376, grad_fn=<NegBackward>)
# 769 tensor(0.2564, grad_fn=<NegBackward>)
# 770 tensor(0.2105, grad_fn=<NegBackward>)
# 771 tensor(0.1223, grad_fn=<NegBackward>)
# 772 tensor(0.3178, grad_fn=<NegBackward>)
# 773 tensor(0.6908, grad_fn=<NegBackward>)
# 774 tensor(0.5841, grad_fn=<NegBackward>)
# 775 tensor(0.5766, grad_fn=<NegBackward>)
# 776 tensor(0.2955, grad_fn=<NegBackward>)
# 777 tensor(0.2178, grad_fn=<NegBackward>)
# 778 tensor(0.3416, grad_fn=<NegBackward>)
# 779 tensor(0.6152, grad_fn=<NegBackward>)
# 780 tensor(0.2382, grad_fn=<NegBackward>)
# 781 tensor(0.4012, grad_fn=<NegBackward>)
# 0 tensor(0.2866, grad_fn=<NegBackward>)
# 1 tensor(0.2079, grad_fn=<NegBackward>)
# 2 tensor(0.4777, grad_fn=<NegBackward>)
# 3 tensor(0.3216, grad_fn=<NegBackward>)
# 4 tensor(0.3735, grad_fn=<NegBackward>)
# 5 tensor(0.1325, grad_fn=<NegBackward>)
# 6 tensor(0.2009, grad_fn=<NegBackward>)
# 7 tensor(0.4637, grad_fn=<NegBackward>)
# 8 tensor(0.2246, grad_fn=<NegBackward>)
# 9 tensor(0.4290, grad_fn=<NegBackward>)
# 10 tensor(0.3475, grad_fn=<NegBackward>)
# 11 tensor(0.2143, grad_fn=<NegBackward>)
# 12 tensor(0.3096, grad_fn=<NegBackward>)
# 13 tensor(0.5543, grad_fn=<NegBackward>)
# 14 tensor(0.4020, grad_fn=<NegBackward>)
# 15 tensor(0.2824, grad_fn=<NegBackward>)
# 16 tensor(0.6016, grad_fn=<NegBackward>)
# 17 tensor(0.6337, grad_fn=<NegBackward>)
# 18 tensor(0.0880, grad_fn=<NegBackward>)
# 19 tensor(0.5453, grad_fn=<NegBackward>)
# 20 tensor(0.3703, grad_fn=<NegBackward>)
# 21 tensor(0.6856, grad_fn=<NegBackward>)
# 22 tensor(0.2388, grad_fn=<NegBackward>)
# 23 tensor(0.3041, grad_fn=<NegBackward>)
# 24 tensor(0.3446, grad_fn=<NegBackward>)
# 25 tensor(0.1850, grad_fn=<NegBackward>)
# 26 tensor(0.2389, grad_fn=<NegBackward>)
# 27 tensor(0.2052, grad_fn=<NegBackward>)
# 28 tensor(0.2732, grad_fn=<NegBackward>)
# 29 tensor(0.1189, grad_fn=<NegBackward>)
# 30 tensor(0.2085, grad_fn=<NegBackward>)
# 31 tensor(0.2745, grad_fn=<NegBackward>)
# 32 tensor(0.3322, grad_fn=<NegBackward>)
# 33 tensor(0.1636, grad_fn=<NegBackward>)
# 34 tensor(0.3099, grad_fn=<NegBackward>)
# 35 tensor(0.1420, grad_fn=<NegBackward>)
# 36 tensor(0.1650, grad_fn=<NegBackward>)
# 37 tensor(0.3371, grad_fn=<NegBackward>)
# 38 tensor(0.1368, grad_fn=<NegBackward>)
# 39 tensor(0.1162, grad_fn=<NegBackward>)
# 40 tensor(0.1989, grad_fn=<NegBackward>)
# 41 tensor(0.4219, grad_fn=<NegBackward>)
# 42 tensor(0.2695, grad_fn=<NegBackward>)
# 43 tensor(0.3415, grad_fn=<NegBackward>)
# 44 tensor(0.2227, grad_fn=<NegBackward>)
# 45 tensor(0.2158, grad_fn=<NegBackward>)
# 46 tensor(0.2499, grad_fn=<NegBackward>)
# 47 tensor(0.4126, grad_fn=<NegBackward>)
# 48 tensor(0.2391, grad_fn=<NegBackward>)
# 49 tensor(0.1526, grad_fn=<NegBackward>)
# 50 tensor(0.3365, grad_fn=<NegBackward>)
# 51 tensor(0.2996, grad_fn=<NegBackward>)
# 52 tensor(0.2330, grad_fn=<NegBackward>)
# 53 tensor(0.2123, grad_fn=<NegBackward>)
# 54 tensor(0.2513, grad_fn=<NegBackward>)
# 55 tensor(0.2664, grad_fn=<NegBackward>)
# 56 tensor(0.1164, grad_fn=<NegBackward>)
# 57 tensor(0.5052, grad_fn=<NegBackward>)
# 58 tensor(0.4073, grad_fn=<NegBackward>)
# 59 tensor(0.3615, grad_fn=<NegBackward>)
# 60 tensor(0.1337, grad_fn=<NegBackward>)
# 61 tensor(0.1189, grad_fn=<NegBackward>)
# 62 tensor(0.2967, grad_fn=<NegBackward>)
# 63 tensor(0.4167, grad_fn=<NegBackward>)
# 64 tensor(0.4109, grad_fn=<NegBackward>)
# 65 tensor(0.3498, grad_fn=<NegBackward>)
# 66 tensor(0.3129, grad_fn=<NegBackward>)
# 67 tensor(0.2138, grad_fn=<NegBackward>)
# 68 tensor(0.2436, grad_fn=<NegBackward>)
# 69 tensor(0.2118, grad_fn=<NegBackward>)
# 70 tensor(0.2583, grad_fn=<NegBackward>)
# 71 tensor(0.1140, grad_fn=<NegBackward>)
# 72 tensor(0.3613, grad_fn=<NegBackward>)
# 73 tensor(0.2089, grad_fn=<NegBackward>)
# 74 tensor(0.3131, grad_fn=<NegBackward>)
# 75 tensor(0.2973, grad_fn=<NegBackward>)
# 76 tensor(0.1788, grad_fn=<NegBackward>)
# 77 tensor(0.5025, grad_fn=<NegBackward>)
# 78 tensor(0.2800, grad_fn=<NegBackward>)
# 79 tensor(0.2601, grad_fn=<NegBackward>)
# 80 tensor(0.6284, grad_fn=<NegBackward>)
# 81 tensor(0.2136, grad_fn=<NegBackward>)
# 82 tensor(0.3608, grad_fn=<NegBackward>)
# 83 tensor(0.2590, grad_fn=<NegBackward>)
# 84 tensor(0.2327, grad_fn=<NegBackward>)
# 85 tensor(0.0975, grad_fn=<NegBackward>)
# 86 tensor(0.3749, grad_fn=<NegBackward>)
# 87 tensor(0.2522, grad_fn=<NegBackward>)
# 88 tensor(0.3138, grad_fn=<NegBackward>)
# 89 tensor(0.2894, grad_fn=<NegBackward>)
# 90 tensor(0.2144, grad_fn=<NegBackward>)
# 91 tensor(0.3667, grad_fn=<NegBackward>)
# 92 tensor(0.2755, grad_fn=<NegBackward>)
# 93 tensor(0.2404, grad_fn=<NegBackward>)
# 94 tensor(0.1557, grad_fn=<NegBackward>)
# 95 tensor(0.3372, grad_fn=<NegBackward>)
# 96 tensor(0.1288, grad_fn=<NegBackward>)
# 97 tensor(0.1932, grad_fn=<NegBackward>)
# 98 tensor(0.1368, grad_fn=<NegBackward>)
# 99 tensor(0.1529, grad_fn=<NegBackward>)
# 100 tensor(0.2589, grad_fn=<NegBackward>)
# 101 tensor(0.3848, grad_fn=<NegBackward>)
# 102 tensor(0.1673, grad_fn=<NegBackward>)
# 103 tensor(0.2050, grad_fn=<NegBackward>)
# 104 tensor(0.2120, grad_fn=<NegBackward>)
# 105 tensor(0.1604, grad_fn=<NegBackward>)
# 106 tensor(0.3841, grad_fn=<NegBackward>)
# 107 tensor(0.4218, grad_fn=<NegBackward>)
# 108 tensor(0.4687, grad_fn=<NegBackward>)
# 109 tensor(0.5781, grad_fn=<NegBackward>)
# 110 tensor(0.2155, grad_fn=<NegBackward>)
# 111 tensor(0.3489, grad_fn=<NegBackward>)
# 112 tensor(0.3707, grad_fn=<NegBackward>)
# 113 tensor(0.4264, grad_fn=<NegBackward>)
# 114 tensor(0.4428, grad_fn=<NegBackward>)
# 115 tensor(0.1903, grad_fn=<NegBackward>)
# 116 tensor(0.2087, grad_fn=<NegBackward>)
# 117 tensor(0.3106, grad_fn=<NegBackward>)
# 118 tensor(0.2115, grad_fn=<NegBackward>)
# 119 tensor(0.3125, grad_fn=<NegBackward>)
# 120 tensor(0.2472, grad_fn=<NegBackward>)
# 121 tensor(0.2667, grad_fn=<NegBackward>)
# 122 tensor(0.4904, grad_fn=<NegBackward>)
# 123 tensor(0.3993, grad_fn=<NegBackward>)
# 124 tensor(0.2440, grad_fn=<NegBackward>)
# 125 tensor(0.2136, grad_fn=<NegBackward>)
# 126 tensor(0.4119, grad_fn=<NegBackward>)
# 127 tensor(0.1759, grad_fn=<NegBackward>)
# 128 tensor(0.5716, grad_fn=<NegBackward>)
# 129 tensor(0.3286, grad_fn=<NegBackward>)
# 130 tensor(0.1616, grad_fn=<NegBackward>)
# 131 tensor(0.3022, grad_fn=<NegBackward>)
# 132 tensor(0.5382, grad_fn=<NegBackward>)
# 133 tensor(0.2518, grad_fn=<NegBackward>)
# 134 tensor(0.2672, grad_fn=<NegBackward>)
# 135 tensor(0.5413, grad_fn=<NegBackward>)
# 136 tensor(0.7965, grad_fn=<NegBackward>)
# 137 tensor(0.5205, grad_fn=<NegBackward>)
# 138 tensor(0.5576, grad_fn=<NegBackward>)
# 139 tensor(0.3961, grad_fn=<NegBackward>)
# 140 tensor(0.2383, grad_fn=<NegBackward>)
# 141 tensor(0.1448, grad_fn=<NegBackward>)
# 142 tensor(0.4295, grad_fn=<NegBackward>)
# 143 tensor(0.2360, grad_fn=<NegBackward>)
# 144 tensor(0.3912, grad_fn=<NegBackward>)
# 145 tensor(0.3232, grad_fn=<NegBackward>)
# 146 tensor(0.3587, grad_fn=<NegBackward>)
# 147 tensor(0.5020, grad_fn=<NegBackward>)
# 148 tensor(0.2601, grad_fn=<NegBackward>)
# 149 tensor(0.3713, grad_fn=<NegBackward>)
# 150 tensor(0.1986, grad_fn=<NegBackward>)
# 151 tensor(0.0882, grad_fn=<NegBackward>)
# 152 tensor(0.4453, grad_fn=<NegBackward>)
# 153 tensor(0.1116, grad_fn=<NegBackward>)
# 154 tensor(0.1732, grad_fn=<NegBackward>)
# 155 tensor(0.2518, grad_fn=<NegBackward>)
# 156 tensor(0.3395, grad_fn=<NegBackward>)
# 157 tensor(0.1856, grad_fn=<NegBackward>)
# 158 tensor(0.2262, grad_fn=<NegBackward>)
# 159 tensor(0.5026, grad_fn=<NegBackward>)
# 160 tensor(0.2292, grad_fn=<NegBackward>)
# 161 tensor(0.2133, grad_fn=<NegBackward>)
# 162 tensor(0.1470, grad_fn=<NegBackward>)
# 163 tensor(0.2084, grad_fn=<NegBackward>)
# 164 tensor(0.0954, grad_fn=<NegBackward>)
# 165 tensor(0.1296, grad_fn=<NegBackward>)
# 166 tensor(0.2196, grad_fn=<NegBackward>)
# 167 tensor(0.3983, grad_fn=<NegBackward>)
# 168 tensor(0.2801, grad_fn=<NegBackward>)
# 169 tensor(0.2430, grad_fn=<NegBackward>)
# 170 tensor(0.2095, grad_fn=<NegBackward>)
# 171 tensor(0.2725, grad_fn=<NegBackward>)
# 172 tensor(0.2377, grad_fn=<NegBackward>)
# 173 tensor(0.1617, grad_fn=<NegBackward>)
# 174 tensor(0.1321, grad_fn=<NegBackward>)
# 175 tensor(0.3316, grad_fn=<NegBackward>)
# 176 tensor(0.1509, grad_fn=<NegBackward>)
# 177 tensor(0.2014, grad_fn=<NegBackward>)
# 178 tensor(0.2351, grad_fn=<NegBackward>)
# 179 tensor(0.2759, grad_fn=<NegBackward>)
# 180 tensor(0.5602, grad_fn=<NegBackward>)
# 181 tensor(0.4143, grad_fn=<NegBackward>)
# 182 tensor(0.5541, grad_fn=<NegBackward>)
# 183 tensor(0.4482, grad_fn=<NegBackward>)
# 184 tensor(0.1882, grad_fn=<NegBackward>)
# 185 tensor(0.3188, grad_fn=<NegBackward>)
# 186 tensor(0.2098, grad_fn=<NegBackward>)
# 187 tensor(0.2212, grad_fn=<NegBackward>)
# 188 tensor(0.3217, grad_fn=<NegBackward>)
# 189 tensor(0.2147, grad_fn=<NegBackward>)
# 190 tensor(0.4653, grad_fn=<NegBackward>)
# 191 tensor(0.2654, grad_fn=<NegBackward>)
# 192 tensor(0.3059, grad_fn=<NegBackward>)
# 193 tensor(0.3421, grad_fn=<NegBackward>)
# 194 tensor(0.3023, grad_fn=<NegBackward>)
# 195 tensor(0.3960, grad_fn=<NegBackward>)
# 196 tensor(0.6349, grad_fn=<NegBackward>)
# 197 tensor(0.6511, grad_fn=<NegBackward>)
# 198 tensor(0.5041, grad_fn=<NegBackward>)
# 199 tensor(0.3478, grad_fn=<NegBackward>)
# 200 tensor(0.1924, grad_fn=<NegBackward>)
# 201 tensor(0.2480, grad_fn=<NegBackward>)
# 202 tensor(0.5298, grad_fn=<NegBackward>)
# 203 tensor(0.5759, grad_fn=<NegBackward>)
# 204 tensor(0.4642, grad_fn=<NegBackward>)
# 205 tensor(0.4025, grad_fn=<NegBackward>)
# 206 tensor(0.2443, grad_fn=<NegBackward>)
# 207 tensor(0.2826, grad_fn=<NegBackward>)
# 208 tensor(0.2598, grad_fn=<NegBackward>)
# 209 tensor(0.3048, grad_fn=<NegBackward>)
# 210 tensor(0.1949, grad_fn=<NegBackward>)
# 211 tensor(0.3843, grad_fn=<NegBackward>)
# 212 tensor(0.1218, grad_fn=<NegBackward>)
# 213 tensor(0.4523, grad_fn=<NegBackward>)
# 214 tensor(0.4203, grad_fn=<NegBackward>)
# 215 tensor(0.2041, grad_fn=<NegBackward>)
# 216 tensor(0.3772, grad_fn=<NegBackward>)
# 217 tensor(0.2917, grad_fn=<NegBackward>)
# 218 tensor(0.6190, grad_fn=<NegBackward>)
# 219 tensor(0.4877, grad_fn=<NegBackward>)
# 220 tensor(0.3837, grad_fn=<NegBackward>)
# 221 tensor(0.3405, grad_fn=<NegBackward>)
# 222 tensor(0.3379, grad_fn=<NegBackward>)
# 223 tensor(0.4004, grad_fn=<NegBackward>)
# 224 tensor(0.7726, grad_fn=<NegBackward>)
# 225 tensor(0.3146, grad_fn=<NegBackward>)
# 226 tensor(0.2666, grad_fn=<NegBackward>)
# 227 tensor(0.3952, grad_fn=<NegBackward>)
# 228 tensor(0.4102, grad_fn=<NegBackward>)
# 229 tensor(0.4350, grad_fn=<NegBackward>)
# 230 tensor(0.5845, grad_fn=<NegBackward>)
# 231 tensor(0.6735, grad_fn=<NegBackward>)
# 232 tensor(0.2612, grad_fn=<NegBackward>)
# 233 tensor(0.2238, grad_fn=<NegBackward>)
# 234 tensor(0.2180, grad_fn=<NegBackward>)
# 235 tensor(0.2190, grad_fn=<NegBackward>)
# 236 tensor(0.5438, grad_fn=<NegBackward>)
# 237 tensor(0.3091, grad_fn=<NegBackward>)
# 238 tensor(0.2747, grad_fn=<NegBackward>)
# 239 tensor(0.2278, grad_fn=<NegBackward>)
# 240 tensor(0.1782, grad_fn=<NegBackward>)
# 241 tensor(0.2490, grad_fn=<NegBackward>)
# 242 tensor(0.3102, grad_fn=<NegBackward>)
# 243 tensor(0.2426, grad_fn=<NegBackward>)
# 244 tensor(0.1988, grad_fn=<NegBackward>)
# 245 tensor(0.3429, grad_fn=<NegBackward>)
# 246 tensor(0.3624, grad_fn=<NegBackward>)
# 247 tensor(0.2924, grad_fn=<NegBackward>)
# 248 tensor(0.2350, grad_fn=<NegBackward>)
# 249 tensor(0.6186, grad_fn=<NegBackward>)
# 250 tensor(0.4940, grad_fn=<NegBackward>)
# 251 tensor(0.2102, grad_fn=<NegBackward>)
# 252 tensor(0.1590, grad_fn=<NegBackward>)
# 253 tensor(0.2361, grad_fn=<NegBackward>)
# 254 tensor(0.2697, grad_fn=<NegBackward>)
# 255 tensor(0.2882, grad_fn=<NegBackward>)
# 256 tensor(0.1853, grad_fn=<NegBackward>)
# 257 tensor(0.2986, grad_fn=<NegBackward>)
# 258 tensor(0.4548, grad_fn=<NegBackward>)
# 259 tensor(0.3060, grad_fn=<NegBackward>)
# 260 tensor(0.3648, grad_fn=<NegBackward>)
# 261 tensor(0.2628, grad_fn=<NegBackward>)
# 262 tensor(0.3677, grad_fn=<NegBackward>)
# 263 tensor(0.2565, grad_fn=<NegBackward>)
# 264 tensor(0.2723, grad_fn=<NegBackward>)
# 265 tensor(0.3543, grad_fn=<NegBackward>)
# 266 tensor(0.3396, grad_fn=<NegBackward>)
# 267 tensor(0.2915, grad_fn=<NegBackward>)
# 268 tensor(0.3333, grad_fn=<NegBackward>)
# 269 tensor(0.3975, grad_fn=<NegBackward>)
# 270 tensor(0.1500, grad_fn=<NegBackward>)
# 271 tensor(0.2970, grad_fn=<NegBackward>)
# 272 tensor(0.2353, grad_fn=<NegBackward>)
# 273 tensor(0.4032, grad_fn=<NegBackward>)
# 274 tensor(0.5232, grad_fn=<NegBackward>)
# 275 tensor(0.2383, grad_fn=<NegBackward>)
# 276 tensor(0.3645, grad_fn=<NegBackward>)
# 277 tensor(0.3062, grad_fn=<NegBackward>)
# 278 tensor(0.4682, grad_fn=<NegBackward>)
# 279 tensor(0.2630, grad_fn=<NegBackward>)
# 280 tensor(0.2369, grad_fn=<NegBackward>)
# 281 tensor(0.2564, grad_fn=<NegBackward>)
# 282 tensor(0.2817, grad_fn=<NegBackward>)
# 283 tensor(0.1561, grad_fn=<NegBackward>)
# 284 tensor(0.1410, grad_fn=<NegBackward>)
# 285 tensor(0.2115, grad_fn=<NegBackward>)
# 286 tensor(0.2515, grad_fn=<NegBackward>)
# 287 tensor(0.2700, grad_fn=<NegBackward>)
# 288 tensor(0.3151, grad_fn=<NegBackward>)
# 289 tensor(0.2463, grad_fn=<NegBackward>)
# 290 tensor(0.4150, grad_fn=<NegBackward>)
# 291 tensor(0.2007, grad_fn=<NegBackward>)
# 292 tensor(0.3603, grad_fn=<NegBackward>)
# 293 tensor(0.1379, grad_fn=<NegBackward>)
# 294 tensor(0.3211, grad_fn=<NegBackward>)
# 295 tensor(0.1573, grad_fn=<NegBackward>)
# 296 tensor(0.1793, grad_fn=<NegBackward>)
# 297 tensor(0.3280, grad_fn=<NegBackward>)
# 298 tensor(0.3021, grad_fn=<NegBackward>)
# 299 tensor(0.2209, grad_fn=<NegBackward>)
# 300 tensor(0.3423, grad_fn=<NegBackward>)
# 301 tensor(0.2094, grad_fn=<NegBackward>)
# 302 tensor(0.2802, grad_fn=<NegBackward>)
# 303 tensor(0.2969, grad_fn=<NegBackward>)
# 304 tensor(0.3177, grad_fn=<NegBackward>)
# 305 tensor(0.3460, grad_fn=<NegBackward>)
# 306 tensor(0.2293, grad_fn=<NegBackward>)
# 307 tensor(0.1410, grad_fn=<NegBackward>)
# 308 tensor(0.0967, grad_fn=<NegBackward>)
# 309 tensor(0.4283, grad_fn=<NegBackward>)
# 310 tensor(0.1603, grad_fn=<NegBackward>)
# 311 tensor(0.2809, grad_fn=<NegBackward>)
# 312 tensor(0.3237, grad_fn=<NegBackward>)
# 313 tensor(0.3326, grad_fn=<NegBackward>)
# 314 tensor(0.1951, grad_fn=<NegBackward>)
# 315 tensor(0.5254, grad_fn=<NegBackward>)
# 316 tensor(0.2037, grad_fn=<NegBackward>)
# 317 tensor(0.2686, grad_fn=<NegBackward>)
# 318 tensor(0.1653, grad_fn=<NegBackward>)
# 319 tensor(0.1938, grad_fn=<NegBackward>)
# 320 tensor(0.1849, grad_fn=<NegBackward>)
# 321 tensor(0.4058, grad_fn=<NegBackward>)
# 322 tensor(0.2728, grad_fn=<NegBackward>)
# 323 tensor(0.5098, grad_fn=<NegBackward>)
# 324 tensor(0.3538, grad_fn=<NegBackward>)
# 325 tensor(0.3954, grad_fn=<NegBackward>)
# 326 tensor(0.6136, grad_fn=<NegBackward>)
# 327 tensor(0.7077, grad_fn=<NegBackward>)
# 328 tensor(0.4080, grad_fn=<NegBackward>)
# 329 tensor(0.3696, grad_fn=<NegBackward>)
# 330 tensor(0.2913, grad_fn=<NegBackward>)
# 331 tensor(0.2923, grad_fn=<NegBackward>)
# 332 tensor(0.1605, grad_fn=<NegBackward>)
# 333 tensor(0.2870, grad_fn=<NegBackward>)
# 334 tensor(0.3039, grad_fn=<NegBackward>)
# 335 tensor(0.0899, grad_fn=<NegBackward>)
# 336 tensor(0.2100, grad_fn=<NegBackward>)
# 337 tensor(0.5305, grad_fn=<NegBackward>)
# 338 tensor(0.2621, grad_fn=<NegBackward>)
# 339 tensor(0.2467, grad_fn=<NegBackward>)
# 340 tensor(0.0870, grad_fn=<NegBackward>)
# 341 tensor(0.1052, grad_fn=<NegBackward>)
# 342 tensor(0.2722, grad_fn=<NegBackward>)
# 343 tensor(0.3406, grad_fn=<NegBackward>)
# 344 tensor(0.1045, grad_fn=<NegBackward>)
# 345 tensor(0.3559, grad_fn=<NegBackward>)
# 346 tensor(0.4081, grad_fn=<NegBackward>)
# 347 tensor(0.4718, grad_fn=<NegBackward>)
# 348 tensor(0.2897, grad_fn=<NegBackward>)
# 349 tensor(0.0742, grad_fn=<NegBackward>)
# 350 tensor(0.2597, grad_fn=<NegBackward>)
# 351 tensor(0.5228, grad_fn=<NegBackward>)
# 352 tensor(0.6592, grad_fn=<NegBackward>)
# 353 tensor(0.4510, grad_fn=<NegBackward>)
# 354 tensor(0.2527, grad_fn=<NegBackward>)
# 355 tensor(0.2584, grad_fn=<NegBackward>)
# 356 tensor(0.2563, grad_fn=<NegBackward>)
# 357 tensor(0.2099, grad_fn=<NegBackward>)
# 358 tensor(0.0938, grad_fn=<NegBackward>)
# 359 tensor(0.2649, grad_fn=<NegBackward>)
# 360 tensor(0.4325, grad_fn=<NegBackward>)
# 361 tensor(0.3286, grad_fn=<NegBackward>)
# 362 tensor(0.3258, grad_fn=<NegBackward>)
# 363 tensor(0.1207, grad_fn=<NegBackward>)
# 364 tensor(0.1989, grad_fn=<NegBackward>)
# 365 tensor(0.2239, grad_fn=<NegBackward>)
# ...
# 402 tensor(0.2264, grad_fn=<NegBackward>)
# 403 tensor(0.4147, grad_fn=<NegBackward>)
# 404 tensor(0.1631, grad_fn=<NegBackward>)
# 405 tensor(0.2290, grad_fn=<NegBackward>)
# 406 tensor(0.1978, grad_fn=<NegBackward>)
# 407 tensor(0.2405, grad_fn=<NegBackward>)
# 408 tensor(0.1735, grad_fn=<NegBackward>)
# 409 tensor(0.1772, grad_fn=<NegBackward>)
# 410 tensor(0.3090, grad_fn=<NegBackward>)
# 411 tensor(0.2858, grad_fn=<NegBackward>)
# 412 tensor(0.5824, grad_fn=<NegBackward>)
# 413 tensor(0.3313, grad_fn=<NegBackward>)
# 414 tensor(0.3745, grad_fn=<NegBackward>)
# 415 tensor(0.3467, grad_fn=<NegBackward>)
# 416 tensor(0.5817, grad_fn=<NegBackward>)
# 417 tensor(0.6143, grad_fn=<NegBackward>)
# 418 tensor(0.3742, grad_fn=<NegBackward>)
# 419 tensor(0.3715, grad_fn=<NegBackward>)
# 420 tensor(0.4850, grad_fn=<NegBackward>)
# 421 tensor(0.1103, grad_fn=<NegBackward>)
# 422 tensor(0.1650, grad_fn=<NegBackward>)
# 423 tensor(0.2191, grad_fn=<NegBackward>)
# 424 tensor(0.7308, grad_fn=<NegBackward>)
# 425 tensor(0.3927, grad_fn=<NegBackward>)
# 426 tensor(0.1663, grad_fn=<NegBackward>)
# 427 tensor(0.2782, grad_fn=<NegBackward>)
# 428 tensor(0.2863, grad_fn=<NegBackward>)
# 429 tensor(0.3810, grad_fn=<NegBackward>)
# 430 tensor(0.2228, grad_fn=<NegBackward>)
# 431 tensor(0.3355, grad_fn=<NegBackward>)
# 432 tensor(0.3060, grad_fn=<NegBackward>)
# 433 tensor(0.2115, grad_fn=<NegBackward>)
# 434 tensor(0.3277, grad_fn=<NegBackward>)
# 435 tensor(0.2301, grad_fn=<NegBackward>)
# 436 tensor(0.1555, grad_fn=<NegBackward>)
# 437 tensor(0.1857, grad_fn=<NegBackward>)
# 438 tensor(0.1476, grad_fn=<NegBackward>)
# 439 tensor(0.2857, grad_fn=<NegBackward>)
# 440 tensor(0.2571, grad_fn=<NegBackward>)
# 441 tensor(0.2168, grad_fn=<NegBackward>)
# 442 tensor(0.1110, grad_fn=<NegBackward>)
# 443 tensor(0.7106, grad_fn=<NegBackward>)
# 444 tensor(0.1923, grad_fn=<NegBackward>)
# 445 tensor(0.3420, grad_fn=<NegBackward>)
# 446 tensor(0.3194, grad_fn=<NegBackward>)
# 447 tensor(0.8356, grad_fn=<NegBackward>)
# 448 tensor(0.2576, grad_fn=<NegBackward>)
# 449 tensor(0.2192, grad_fn=<NegBackward>)
# 450 tensor(0.1766, grad_fn=<NegBackward>)
# 451 tensor(0.1233, grad_fn=<NegBackward>)
# 452 tensor(0.2960, grad_fn=<NegBackward>)
# 453 tensor(0.1294, grad_fn=<NegBackward>)
# 454 tensor(0.3310, grad_fn=<NegBackward>)
# 455 tensor(0.4032, grad_fn=<NegBackward>)
# 456 tensor(0.3860, grad_fn=<NegBackward>)
# 457 tensor(0.2927, grad_fn=<NegBackward>)
# 458 tensor(0.2580, grad_fn=<NegBackward>)
# 459 tensor(0.2972, grad_fn=<NegBackward>)
# 460 tensor(0.1946, grad_fn=<NegBackward>)
# 461 tensor(0.2345, grad_fn=<NegBackward>)
# 462 tensor(0.2469, grad_fn=<NegBackward>)
# 463 tensor(0.2819, grad_fn=<NegBackward>)
# 464 tensor(0.4311, grad_fn=<NegBackward>)
# 465 tensor(0.2090, grad_fn=<NegBackward>)
# 466 tensor(0.5199, grad_fn=<NegBackward>)
# 467 tensor(0.4367, grad_fn=<NegBackward>)
# 468 tensor(0.4185, grad_fn=<NegBackward>)
# 469 tensor(0.3154, grad_fn=<NegBackward>)
# 470 tensor(0.3659, grad_fn=<NegBackward>)
# 471 tensor(0.4160, grad_fn=<NegBackward>)
# 472 tensor(0.3735, grad_fn=<NegBackward>)
# 473 tensor(0.2201, grad_fn=<NegBackward>)
# 474 tensor(0.1640, grad_fn=<NegBackward>)
# 475 tensor(0.2675, grad_fn=<NegBackward>)
# 476 tensor(0.3500, grad_fn=<NegBackward>)
# 477 tensor(0.2583, grad_fn=<NegBackward>)
# 478 tensor(0.4319, grad_fn=<NegBackward>)
# 479 tensor(0.3316, grad_fn=<NegBackward>)
# 480 tensor(0.3483, grad_fn=<NegBackward>)
# 481 tensor(0.2817, grad_fn=<NegBackward>)
# 482 tensor(0.4216, grad_fn=<NegBackward>)
# 483 tensor(0.2508, grad_fn=<NegBackward>)
# 484 tensor(0.3954, grad_fn=<NegBackward>)
# 485 tensor(0.3214, grad_fn=<NegBackward>)
# 486 tensor(0.5057, grad_fn=<NegBackward>)
# 487 tensor(0.5609, grad_fn=<NegBackward>)
# 488 tensor(0.3485, grad_fn=<NegBackward>)
# 489 tensor(0.7195, grad_fn=<NegBackward>)
# 490 tensor(0.5379, grad_fn=<NegBackward>)
# 491 tensor(0.3764, grad_fn=<NegBackward>)
# 492 tensor(0.1439, grad_fn=<NegBackward>)
# 493 tensor(0.2894, grad_fn=<NegBackward>)
# 494 tensor(0.4337, grad_fn=<NegBackward>)
# 495 tensor(0.6066, grad_fn=<NegBackward>)
# 496 tensor(0.3716, grad_fn=<NegBackward>)
# 497 tensor(0.2789, grad_fn=<NegBackward>)
# 498 tensor(0.2696, grad_fn=<NegBackward>)
# 499 tensor(0.3399, grad_fn=<NegBackward>)
# 500 tensor(0.3554, grad_fn=<NegBackward>)
# 501 tensor(0.3330, grad_fn=<NegBackward>)
# 502 tensor(0.4312, grad_fn=<NegBackward>)
# 503 tensor(0.3148, grad_fn=<NegBackward>)
# 504 tensor(0.4523, grad_fn=<NegBackward>)
# 505 tensor(0.4415, grad_fn=<NegBackward>)
# 506 tensor(0.4353, grad_fn=<NegBackward>)
# 507 tensor(0.4010, grad_fn=<NegBackward>)
# 508 tensor(0.2112, grad_fn=<NegBackward>)
# 509 tensor(0.1061, grad_fn=<NegBackward>)
# 510 tensor(0.4568, grad_fn=<NegBackward>)
# 511 tensor(0.2583, grad_fn=<NegBackward>)
# 512 tensor(0.5350, grad_fn=<NegBackward>)
# 513 tensor(0.2555, grad_fn=<NegBackward>)
# 514 tensor(0.3614, grad_fn=<NegBackward>)
# 515 tensor(0.2199, grad_fn=<NegBackward>)
# 516 tensor(0.2487, grad_fn=<NegBackward>)
# 517 tensor(0.1963, grad_fn=<NegBackward>)
# 518 tensor(0.1828, grad_fn=<NegBackward>)
# 519 tensor(0.2795, grad_fn=<NegBackward>)
# 520 tensor(0.4035, grad_fn=<NegBackward>)
# 521 tensor(0.3637, grad_fn=<NegBackward>)
# 522 tensor(0.3277, grad_fn=<NegBackward>)
# 523 tensor(0.2839, grad_fn=<NegBackward>)
# 524 tensor(0.2620, grad_fn=<NegBackward>)
# 525 tensor(0.1570, grad_fn=<NegBackward>)
# 526 tensor(0.1579, grad_fn=<NegBackward>)
# 527 tensor(0.3509, grad_fn=<NegBackward>)
# 528 tensor(0.1149, grad_fn=<NegBackward>)
# 529 tensor(0.0872, grad_fn=<NegBackward>)
# 530 tensor(0.1478, grad_fn=<NegBackward>)
# 531 tensor(0.1725, grad_fn=<NegBackward>)
# 532 tensor(0.2485, grad_fn=<NegBackward>)
# 533 tensor(0.1682, grad_fn=<NegBackward>)
# 534 tensor(0.1936, grad_fn=<NegBackward>)
# 535 tensor(0.1824, grad_fn=<NegBackward>)
# 536 tensor(0.1664, grad_fn=<NegBackward>)
# 537 tensor(0.3095, grad_fn=<NegBackward>)
# 538 tensor(0.4218, grad_fn=<NegBackward>)
# 539 tensor(0.4988, grad_fn=<NegBackward>)
# 540 tensor(0.2976, grad_fn=<NegBackward>)
# 541 tensor(0.4373, grad_fn=<NegBackward>)
# 542 tensor(0.3724, grad_fn=<NegBackward>)
# 543 tensor(0.3531, grad_fn=<NegBackward>)
# 544 tensor(0.4852, grad_fn=<NegBackward>)
# 545 tensor(0.2837, grad_fn=<NegBackward>)
# 546 tensor(0.1615, grad_fn=<NegBackward>)
# 547 tensor(0.2995, grad_fn=<NegBackward>)
# 548 tensor(0.1692, grad_fn=<NegBackward>)
# 549 tensor(0.2549, grad_fn=<NegBackward>)
# 550 tensor(0.3268, grad_fn=<NegBackward>)
# 551 tensor(0.1781, grad_fn=<NegBackward>)
# 552 tensor(0.1909, grad_fn=<NegBackward>)
# 553 tensor(0.2849, grad_fn=<NegBackward>)
# 554 tensor(0.4706, grad_fn=<NegBackward>)
# 555 tensor(0.1674, grad_fn=<NegBackward>)
# 556 tensor(0.2976, grad_fn=<NegBackward>)
# 557 tensor(0.2210, grad_fn=<NegBackward>)
# 558 tensor(0.1589, grad_fn=<NegBackward>)
# 559 tensor(0.1340, grad_fn=<NegBackward>)
# 560 tensor(0.2476, grad_fn=<NegBackward>)
# 561 tensor(0.2772, grad_fn=<NegBackward>)
# 562 tensor(0.3150, grad_fn=<NegBackward>)
# 563 tensor(0.3713, grad_fn=<NegBackward>)
# 564 tensor(0.2714, grad_fn=<NegBackward>)
# 565 tensor(0.2457, grad_fn=<NegBackward>)
# 566 tensor(0.2412, grad_fn=<NegBackward>)
# 567 tensor(0.0968, grad_fn=<NegBackward>)
# 568 tensor(0.2852, grad_fn=<NegBackward>)
# 569 tensor(0.3801, grad_fn=<NegBackward>)
# 570 tensor(0.1697, grad_fn=<NegBackward>)
# 571 tensor(0.2493, grad_fn=<NegBackward>)
# 572 tensor(0.1348, grad_fn=<NegBackward>)
# 573 tensor(0.1771, grad_fn=<NegBackward>)
# 574 tensor(0.3214, grad_fn=<NegBackward>)
# 575 tensor(0.2705, grad_fn=<NegBackward>)
# 576 tensor(0.2742, grad_fn=<NegBackward>)
# 577 tensor(0.1504, grad_fn=<NegBackward>)
# 578 tensor(0.2732, grad_fn=<NegBackward>)
# 579 tensor(0.4408, grad_fn=<NegBackward>)
# 580 tensor(0.4365, grad_fn=<NegBackward>)
# 581 tensor(0.2329, grad_fn=<NegBackward>)
# 582 tensor(0.5888, grad_fn=<NegBackward>)
# 583 tensor(0.6826, grad_fn=<NegBackward>)
# 584 tensor(0.9272, grad_fn=<NegBackward>)
# 585 tensor(0.5429, grad_fn=<NegBackward>)
# 586 tensor(0.4856, grad_fn=<NegBackward>)
# 587 tensor(0.2197, grad_fn=<NegBackward>)
# 588 tensor(0.2679, grad_fn=<NegBackward>)
# 589 tensor(0.4981, grad_fn=<NegBackward>)
# 590 tensor(0.2669, grad_fn=<NegBackward>)
# 591 tensor(0.3333, grad_fn=<NegBackward>)
# 592 tensor(0.2660, grad_fn=<NegBackward>)
# 593 tensor(0.4059, grad_fn=<NegBackward>)
# 594 tensor(0.2774, grad_fn=<NegBackward>)
# 595 tensor(0.1872, grad_fn=<NegBackward>)
# 596 tensor(0.1551, grad_fn=<NegBackward>)
# 597 tensor(0.3858, grad_fn=<NegBackward>)
# 598 tensor(0.3200, grad_fn=<NegBackward>)
# 599 tensor(0.3293, grad_fn=<NegBackward>)
# 600 tensor(0.2260, grad_fn=<NegBackward>)
# 601 tensor(0.3424, grad_fn=<NegBackward>)
# 602 tensor(0.3863, grad_fn=<NegBackward>)
# 603 tensor(0.4626, grad_fn=<NegBackward>)
# 604 tensor(0.3236, grad_fn=<NegBackward>)
# 605 tensor(0.2784, grad_fn=<NegBackward>)
# 606 tensor(0.1499, grad_fn=<NegBackward>)
# 607 tensor(0.1491, grad_fn=<NegBackward>)
# 608 tensor(0.1809, grad_fn=<NegBackward>)
# 609 tensor(0.2046, grad_fn=<NegBackward>)
# 610 tensor(0.1472, grad_fn=<NegBackward>)
# 611 tensor(0.2802, grad_fn=<NegBackward>)
# 612 tensor(0.2245, grad_fn=<NegBackward>)
# 613 tensor(0.2637, grad_fn=<NegBackward>)
# 614 tensor(0.8156, grad_fn=<NegBackward>)
# 615 tensor(0.4002, grad_fn=<NegBackward>)
# 616 tensor(0.5189, grad_fn=<NegBackward>)
# 617 tensor(0.2581, grad_fn=<NegBackward>)
# 618 tensor(0.2240, grad_fn=<NegBackward>)
# 619 tensor(0.3132, grad_fn=<NegBackward>)
# 620 tensor(0.2539, grad_fn=<NegBackward>)
# 621 tensor(0.3279, grad_fn=<NegBackward>)
# 622 tensor(0.2137, grad_fn=<NegBackward>)
# 623 tensor(0.2651, grad_fn=<NegBackward>)
# 624 tensor(0.4415, grad_fn=<NegBackward>)
# 625 tensor(0.2061, grad_fn=<NegBackward>)
# 626 tensor(0.3531, grad_fn=<NegBackward>)
# 627 tensor(0.2717, grad_fn=<NegBackward>)
# 628 tensor(0.1677, grad_fn=<NegBackward>)
# 629 tensor(0.2719, grad_fn=<NegBackward>)
# 630 tensor(0.2856, grad_fn=<NegBackward>)
# 631 tensor(0.2003, grad_fn=<NegBackward>)
# 632 tensor(0.3697, grad_fn=<NegBackward>)
# 633 tensor(0.3117, grad_fn=<NegBackward>)
# 634 tensor(0.2699, grad_fn=<NegBackward>)
# 635 tensor(0.2688, grad_fn=<NegBackward>)
# 636 tensor(0.3678, grad_fn=<NegBackward>)
# 637 tensor(0.1766, grad_fn=<NegBackward>)
# 638 tensor(0.1807, grad_fn=<NegBackward>)
# 639 tensor(0.2043, grad_fn=<NegBackward>)
# 640 tensor(0.4807, grad_fn=<NegBackward>)
# 641 tensor(0.2422, grad_fn=<NegBackward>)
# 642 tensor(0.2765, grad_fn=<NegBackward>)
# 643 tensor(0.2264, grad_fn=<NegBackward>)
# 644 tensor(0.3426, grad_fn=<NegBackward>)
# 645 tensor(0.5165, grad_fn=<NegBackward>)
# 646 tensor(0.3085, grad_fn=<NegBackward>)
# 647 tensor(0.6193, grad_fn=<NegBackward>)
# 648 tensor(0.3797, grad_fn=<NegBackward>)
# 649 tensor(0.4121, grad_fn=<NegBackward>)
# 650 tensor(0.1999, grad_fn=<NegBackward>)
# 651 tensor(0.1922, grad_fn=<NegBackward>)
# 652 tensor(0.2726, grad_fn=<NegBackward>)
# 653 tensor(0.2087, grad_fn=<NegBackward>)
# 654 tensor(0.1864, grad_fn=<NegBackward>)
# 655 tensor(0.3233, grad_fn=<NegBackward>)
# 656 tensor(0.5065, grad_fn=<NegBackward>)
# 657 tensor(0.2413, grad_fn=<NegBackward>)
# 658 tensor(0.3241, grad_fn=<NegBackward>)
# 659 tensor(0.3131, grad_fn=<NegBackward>)
# 660 tensor(0.1431, grad_fn=<NegBackward>)
# 661 tensor(0.6704, grad_fn=<NegBackward>)
# 662 tensor(0.2533, grad_fn=<NegBackward>)
# 663 tensor(0.6618, grad_fn=<NegBackward>)
# 664 tensor(0.6222, grad_fn=<NegBackward>)
# 665 tensor(0.1480, grad_fn=<NegBackward>)
# 666 tensor(0.2446, grad_fn=<NegBackward>)
# 667 tensor(0.3420, grad_fn=<NegBackward>)
# 668 tensor(0.3580, grad_fn=<NegBackward>)
# 669 tensor(0.3896, grad_fn=<NegBackward>)
# 670 tensor(0.4280, grad_fn=<NegBackward>)
# 671 tensor(0.4100, grad_fn=<NegBackward>)
# 672 tensor(0.2668, grad_fn=<NegBackward>)
# 673 tensor(0.3163, grad_fn=<NegBackward>)
# 674 tensor(0.2827, grad_fn=<NegBackward>)
# 675 tensor(0.4449, grad_fn=<NegBackward>)
# 676 tensor(0.0900, grad_fn=<NegBackward>)
# 677 tensor(0.2238, grad_fn=<NegBackward>)
# 678 tensor(0.1373, grad_fn=<NegBackward>)
# 679 tensor(0.1427, grad_fn=<NegBackward>)
# 680 tensor(0.3480, grad_fn=<NegBackward>)
# 681 tensor(0.1324, grad_fn=<NegBackward>)
# 682 tensor(0.3758, grad_fn=<NegBackward>)
# 683 tensor(0.1250, grad_fn=<NegBackward>)
# 684 tensor(0.2791, grad_fn=<NegBackward>)
# 685 tensor(0.3971, grad_fn=<NegBackward>)
# 686 tensor(0.3749, grad_fn=<NegBackward>)
# 687 tensor(0.2575, grad_fn=<NegBackward>)
# 688 tensor(0.2021, grad_fn=<NegBackward>)
# 689 tensor(0.4094, grad_fn=<NegBackward>)
# 690 tensor(0.1730, grad_fn=<NegBackward>)
# 691 tensor(0.3595, grad_fn=<NegBackward>)
# 692 tensor(0.3793, grad_fn=<NegBackward>)
# 693 tensor(0.3703, grad_fn=<NegBackward>)
# 694 tensor(0.4737, grad_fn=<NegBackward>)
# 695 tensor(0.2517, grad_fn=<NegBackward>)
# 696 tensor(0.1955, grad_fn=<NegBackward>)
# 697 tensor(0.1589, grad_fn=<NegBackward>)
# 698 tensor(0.1921, grad_fn=<NegBackward>)
# 699 tensor(0.2346, grad_fn=<NegBackward>)
# 700 tensor(0.3669, grad_fn=<NegBackward>)
# 701 tensor(0.5104, grad_fn=<NegBackward>)
# 702 tensor(0.3151, grad_fn=<NegBackward>)
# 703 tensor(0.4962, grad_fn=<NegBackward>)
# 704 tensor(0.4498, grad_fn=<NegBackward>)
# 705 tensor(0.3526, grad_fn=<NegBackward>)
# 706 tensor(0.2561, grad_fn=<NegBackward>)
# 707 tensor(0.2057, grad_fn=<NegBackward>)
# 708 tensor(0.0814, grad_fn=<NegBackward>)
# 709 tensor(0.3356, grad_fn=<NegBackward>)
# 710 tensor(0.6070, grad_fn=<NegBackward>)
# 711 tensor(0.3063, grad_fn=<NegBackward>)
# 712 tensor(0.4490, grad_fn=<NegBackward>)
# 713 tensor(0.2460, grad_fn=<NegBackward>)
# 714 tensor(0.2028, grad_fn=<NegBackward>)
# 715 tensor(0.5086, grad_fn=<NegBackward>)
# 716 tensor(0.3715, grad_fn=<NegBackward>)
# 717 tensor(0.3723, grad_fn=<NegBackward>)
# 718 tensor(0.3252, grad_fn=<NegBackward>)
# 719 tensor(0.3645, grad_fn=<NegBackward>)
# 720 tensor(0.4409, grad_fn=<NegBackward>)
# 721 tensor(0.2554, grad_fn=<NegBackward>)
# 722 tensor(0.5110, grad_fn=<NegBackward>)
# 723 tensor(0.6197, grad_fn=<NegBackward>)
# 724 tensor(0.3716, grad_fn=<NegBackward>)
# 725 tensor(0.4783, grad_fn=<NegBackward>)
# 726 tensor(0.1356, grad_fn=<NegBackward>)
# 727 tensor(0.1472, grad_fn=<NegBackward>)
# 728 tensor(0.2565, grad_fn=<NegBackward>)
# 729 tensor(0.1157, grad_fn=<NegBackward>)
# 730 tensor(0.4374, grad_fn=<NegBackward>)
# 731 tensor(0.0907, grad_fn=<NegBackward>)
# 732 tensor(0.2110, grad_fn=<NegBackward>)
# 733 tensor(0.2372, grad_fn=<NegBackward>)
# 734 tensor(0.2878, grad_fn=<NegBackward>)
# 735 tensor(0.1775, grad_fn=<NegBackward>)
# 736 tensor(0.2155, grad_fn=<NegBackward>)
# 737 tensor(0.2852, grad_fn=<NegBackward>)
# 738 tensor(0.4231, grad_fn=<NegBackward>)
# 739 tensor(0.3018, grad_fn=<NegBackward>)
# 740 tensor(0.2807, grad_fn=<NegBackward>)
# 741 tensor(0.4067, grad_fn=<NegBackward>)
# 742 tensor(0.1423, grad_fn=<NegBackward>)
# 743 tensor(0.6194, grad_fn=<NegBackward>)
# 744 tensor(0.2011, grad_fn=<NegBackward>)
# 745 tensor(0.3673, grad_fn=<NegBackward>)
# 746 tensor(0.3153, grad_fn=<NegBackward>)
# 747 tensor(0.1698, grad_fn=<NegBackward>)
# 748 tensor(0.3790, grad_fn=<NegBackward>)
# 749 tensor(0.4344, grad_fn=<NegBackward>)
# 750 tensor(0.1914, grad_fn=<NegBackward>)
# 751 tensor(0.2794, grad_fn=<NegBackward>)
# 752 tensor(0.1090, grad_fn=<NegBackward>)
# 753 tensor(0.1151, grad_fn=<NegBackward>)
# 754 tensor(0.1815, grad_fn=<NegBackward>)
# 755 tensor(0.5974, grad_fn=<NegBackward>)
# 756 tensor(0.2196, grad_fn=<NegBackward>)
# 757 tensor(0.1582, grad_fn=<NegBackward>)
# 758 tensor(0.2866, grad_fn=<NegBackward>)
# 759 tensor(0.1986, grad_fn=<NegBackward>)
# 760 tensor(0.2955, grad_fn=<NegBackward>)
# 761 tensor(0.1596, grad_fn=<NegBackward>)
# 762 tensor(0.1656, grad_fn=<NegBackward>)
# 763 tensor(0.2241, grad_fn=<NegBackward>)
# 764 tensor(0.5618, grad_fn=<NegBackward>)
# 765 tensor(0.6567, grad_fn=<NegBackward>)
# 766 tensor(0.4185, grad_fn=<NegBackward>)
# 767 tensor(0.2197, grad_fn=<NegBackward>)
# 768 tensor(0.3966, grad_fn=<NegBackward>)
# 769 tensor(0.2458, grad_fn=<NegBackward>)
# 770 tensor(0.2028, grad_fn=<NegBackward>)
# 771 tensor(0.1072, grad_fn=<NegBackward>)
# 772 tensor(0.2809, grad_fn=<NegBackward>)
# 773 tensor(0.6633, grad_fn=<NegBackward>)
# 774 tensor(0.5625, grad_fn=<NegBackward>)
# 775 tensor(0.5504, grad_fn=<NegBackward>)
# 776 tensor(0.2652, grad_fn=<NegBackward>)
# 777 tensor(0.2036, grad_fn=<NegBackward>)
# 778 tensor(0.3158, grad_fn=<NegBackward>)
# 779 tensor(0.6207, grad_fn=<NegBackward>)
# 780 tensor(0.2097, grad_fn=<NegBackward>)
# 781 tensor(0.3111, grad_fn=<NegBackward>)
